# %%
import pandas as pd
import sys
import numpy as np
from unidecode import unidecode

# %%
caged = pd.read_excel("dataset/Economico/Renda e Desenvolvimento/PIB/novo_CAGED_alterado.xlsx", sheet_name="Tabela 8", header=[0,1])

# %%
cod_municipios = pd.read_csv('Código dos Municípios')

# %%
caged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5571 entries, 0 to 5570
# Columns: 260 entries, ('Unnamed: 0_level_0', 'UF') to ('Acumulado do Ano (2024) - Com Ajustes', 'Variação Relativa (%)')
# dtypes: float64(5), int64(160), object(95)
# memory usage: 11.1+ MB

# %%
caged
# Out:
#      Unnamed: 0_level_0  Unnamed: 1_level_0        Unnamed: 2_level_0  \
#                      UF Código do Município                 Município
# 0                    RO              110001  Ro-Alta Floresta D Oeste
# 1                    RO              110002              Ro-Ariquemes
# 2                    RO              110003                 Ro-Cabixi
# 3                    RO              110004                 Ro-Cacoal
# 4                    RO              110005             Ro-Cerejeiras
# ...                 ...                 ...                       ...
# 5566                 GO              522205         Go-Vicentinopolis
# 5567                 GO              522220               Go-Vila Boa
# 5568                 GO              522230          Go-Vila Propicio
# 5569                 DF              530010               Df-Brasilia
# 5570   Não identificado              999999          Não identificado
#
#        Janeiro/2020                                Fevereiro/2020            \
#             Estoque Admissões Desligamentos Saldos        Estoque Admissões
# 0       1957.264255        52            70    -18           1958        67
# 1      16301.673377       562           616    -54          16302       653
# 2        547.751861         9             4      5            548         7
# 3      16104.979525       731           824    -93          16106       848
# 4       1926.743169       133            59     74           1928        84
# ...             ...       ...           ...    ...            ...       ...
# 5566    2175.039216        50            19     31           2177        59
# 5567    1556.530055        59            16     43           1565        73
# 5568     915.507389        31            24      7            916        19
# 5569  847944.410094     25213         24550    663         847945     26798
# 5570            ---         8             1      7            ---         1
#
#                     ... Fevereiro/2024                        \
#      Desligamentos  ...         Saldos Variação Relativa (%)
# 0               55  ...             -8             -0.348129
# 1              604  ...            700              3.723404
# 2                6  ...             13               2.24525
# 3              693  ...             40              0.222173
# 4               61  ...             23              0.930421
# ...            ...  ...            ...                   ...
# 5566            19  ...             99              4.376658
# 5567            11  ...             24              1.716738
# 5568            15  ...             24              2.116402
# 5569         22148  ...           6511              0.670795
# 5570             5  ...              3                   ---
#
#      Últimos 12 Meses** (Mar/23 a Fev/24) - com ajuste                       \
#                                              Admissões Desligamentos Saldos
# 0                                                 1157          1143     14
# 1                                                11719         11065    654
# 2                                                  172           181     -9
# 3                                                11601         10983    618
# 4                                                 1443          1337    106
# ...                                                ...           ...    ...
# 5566                                              1661          1765   -104
# 5567                                              1263          1375   -112
# 5568                                               796           773     23
# 5569                                            412002        371713  40289
# 5570                                             89029         94813  -5784
#
#                            Acumulado do Ano (2024) - Com Ajustes  \
#      Variação Relativa (%)                             Admissões
# 0                 0.615114                                   202
# 1                 3.470232                                  2559
# 2                -1.497504                                    49
# 3                 3.546425                                  1896
# 4                 4.437003                                   307
# ...                    ...                                   ...
# 5566             -4.219067                                   322
# 5567             -7.301173                                   167
# 5568              2.026432                                   129
# 5569              4.300420                                 74321
# 5570            -95.209877                                    20
#
#
#      Desligamentos Saldos Variação Relativa (%)
# 0              205     -3             -0.130833
# 1             2480     79              0.406776
# 2               43      6              1.023891
# 3             1840     56              0.311319
# 4              222     85              3.526971
# ...            ...    ...                   ...
# 5566           151    171              7.808219
# 5567            57    110              8.384146
# 5568           103     26               2.29682
# 5569         64952   9369               0.96809
# 5570            11      9                   ---
#
# [5571 rows x 260 columns]

# %%
cols = caged.columns

# %%
caged.columns = ['_'.join(col) for col in caged.columns]

# %%
caged = caged.rename(columns={'Unnamed: 0_level_0_UF': 'UF', 'Unnamed: 1_level_0_Código do Município': 'Codigo do Municipio', 'Unnamed: 2_level_0_Município': 'Municipio'})

# %%
caged
# Out:
#                     UF  Codigo do Municipio                 Municipio  \
# 0                   RO               110001  Ro-Alta Floresta D Oeste
# 1                   RO               110002              Ro-Ariquemes
# 2                   RO               110003                 Ro-Cabixi
# 3                   RO               110004                 Ro-Cacoal
# 4                   RO               110005             Ro-Cerejeiras
# ...                ...                  ...                       ...
# 5566                GO               522205         Go-Vicentinopolis
# 5567                GO               522220               Go-Vila Boa
# 5568                GO               522230          Go-Vila Propicio
# 5569                DF               530010               Df-Brasilia
# 5570  Não identificado               999999          Não identificado
#
#      Janeiro/2020_Estoque  Janeiro/2020_Admissões  Janeiro/2020_Desligamentos  \
# 0             1957.264255                      52                          70
# 1            16301.673377                     562                         616
# 2              547.751861                       9                           4
# 3            16104.979525                     731                         824
# 4             1926.743169                     133                          59
# ...                   ...                     ...                         ...
# 5566          2175.039216                      50                          19
# 5567          1556.530055                      59                          16
# 5568           915.507389                      31                          24
# 5569        847944.410094                   25213                       24550
# 5570                  ---                       8                           1
#
#       Janeiro/2020_Saldos Fevereiro/2020_Estoque  Fevereiro/2020_Admissões  \
# 0                     -18                   1958                        67
# 1                     -54                  16302                       653
# 2                       5                    548                         7
# 3                     -93                  16106                       848
# 4                      74                   1928                        84
# ...                   ...                    ...                       ...
# 5566                   31                   2177                        59
# 5567                   43                   1565                        73
# 5568                    7                    916                        19
# 5569                  663                 847945                     26798
# 5570                    7                    ---                         1
#
#       Fevereiro/2020_Desligamentos  ...  Fevereiro/2024_Saldos  \
# 0                               55  ...                     -8
# 1                              604  ...                    700
# 2                                6  ...                     13
# 3                              693  ...                     40
# 4                               61  ...                     23
# ...                            ...  ...                    ...
# 5566                            19  ...                     99
# 5567                            11  ...                     24
# 5568                            15  ...                     24
# 5569                         22148  ...                   6511
# 5570                             5  ...                      3
#
#      Fevereiro/2024_Variação Relativa (%)  \
# 0                               -0.348129
# 1                                3.723404
# 2                                 2.24525
# 3                                0.222173
# 4                                0.930421
# ...                                   ...
# 5566                             4.376658
# 5567                             1.716738
# 5568                             2.116402
# 5569                             0.670795
# 5570                                  ---
#
#      Últimos 12 Meses** (Mar/23 a Fev/24) - com ajuste_Admissões  \
# 0                                                  1157
# 1                                                 11719
# 2                                                   172
# 3                                                 11601
# 4                                                  1443
# ...                                                 ...
# 5566                                               1661
# 5567                                               1263
# 5568                                                796
# 5569                                             412002
# 5570                                              89029
#
#       Últimos 12 Meses** (Mar/23 a Fev/24) - com ajuste_Desligamentos  \
# 0                                                  1143
# 1                                                 11065
# 2                                                   181
# 3                                                 10983
# 4                                                  1337
# ...                                                 ...
# 5566                                               1765
# 5567                                               1375
# 5568                                                773
# 5569                                             371713
# 5570                                              94813
#
#       Últimos 12 Meses** (Mar/23 a Fev/24) - com ajuste_Saldos  \
# 0                                                    14
# 1                                                   654
# 2                                                    -9
# 3                                                   618
# 4                                                   106
# ...                                                 ...
# 5566                                               -104
# 5567                                               -112
# 5568                                                 23
# 5569                                              40289
# 5570                                              -5784
#
#       Últimos 12 Meses** (Mar/23 a Fev/24) - com ajuste_Variação Relativa (%)  \
# 0                                              0.615114
# 1                                              3.470232
# 2                                             -1.497504
# 3                                              3.546425
# 4                                              4.437003
# ...                                                 ...
# 5566                                          -4.219067
# 5567                                          -7.301173
# 5568                                           2.026432
# 5569                                           4.300420
# 5570                                         -95.209877
#
#      Acumulado do Ano (2024) - Com Ajustes_Admissões  \
# 0                                                202
# 1                                               2559
# 2                                                 49
# 3                                               1896
# 4                                                307
# ...                                              ...
# 5566                                             322
# 5567                                             167
# 5568                                             129
# 5569                                           74321
# 5570                                              20
#
#      Acumulado do Ano (2024) - Com Ajustes_Desligamentos  \
# 0                                                   205
# 1                                                  2480
# 2                                                    43
# 3                                                  1840
# 4                                                   222
# ...                                                 ...
# 5566                                                151
# 5567                                                 57
# 5568                                                103
# 5569                                              64952
# 5570                                                 11
#
#       Acumulado do Ano (2024) - Com Ajustes_Saldos  \
# 0                                               -3
# 1                                               79
# 2                                                6
# 3                                               56
# 4                                               85
# ...                                            ...
# 5566                                           171
# 5567                                           110
# 5568                                            26
# 5569                                          9369
# 5570                                             9
#
#       Acumulado do Ano (2024) - Com Ajustes_Variação Relativa (%)
# 0                                             -0.130833
# 1                                              0.406776
# 2                                              1.023891
# 3                                              0.311319
# 4                                              3.526971
# ...                                                 ...
# 5566                                           7.808219
# 5567                                           8.384146
# 5568                                            2.29682
# 5569                                            0.96809
# 5570                                                ---
#
# [5571 rows x 260 columns]

# %%
nomes= []
ufs = []
i = 0

for index, row in caged.iterrows():
    if '-' in row['Municipio']:
        tmp = row['Municipio'].split("-")
        nomes.append(tmp[1])

for index, row in caged.iterrows():
    if '-' in row['Municipio']:
        caged.iat[i, 2] = nomes[i]
        i = i+1

# %%
caged = caged.drop(index=5570)

# %%
tmp = list(caged.columns[3:252])

# %%
cmp_Cols = []
for x in tmp:
    cmp_Cols.append(x.split("/")[1])

# %%
cmp_Cols_Idx = pd.Index(cmp_Cols)

# %%
cmp_Cols = list(cmp_Cols_Idx.value_counts().index)

# %%
estoque_cols = [col for col in cmp_Cols if "Estoque" in col]
fixed_cols = ['UF', 'Codigo do Municipio', 'Municipio']
estoque_columns = fixed_cols + [col for col in caged.columns if any(estoque in col for estoque in estoque_cols)]

# %%
caged_estoque = caged[estoque_columns]

# %%
caged_estoque.replace('---', np.nan, inplace=True)
# Out:
# /tmp/ipykernel_4574/783749964.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   caged_estoque.replace('---', np.nan, inplace=True)
# /tmp/ipykernel_4574/783749964.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   caged_estoque.replace('---', np.nan, inplace=True)

# %%
media_estoque_por_ano = pd.DataFrame()
for estoque_col in estoque_cols:
    # Filtrando as colunas que contêm o ano atual
    colunas_ano = [col for col in caged_estoque.columns if estoque_col in col]
    
    # Calculando a média das colunas do ano atual
    media_estoque_por_ano[estoque_col + "_media"] = caged_estoque[colunas_ano].mean(axis=1)

# Adicionando as colunas fixas ao novo DataFrame
media_estoque_por_ano = pd.concat([caged_estoque[fixed_cols], media_estoque_por_ano], axis=1)

# %%
cod_municipios["Município"] = cod_municipios["Município"].apply(lambda x: unidecode(str(x)))

# %%
cod_municipios["Município"] = cod_municipios["Município"].str.replace("'"," ", regex=False)

# %%
media_estoque_por_ano = media_estoque_por_ano.merge(cod_municipios[['Codigo_Municipio','Sigla_UF','Município']], how='right', left_on=["UF", "Municipio"], right_on=["Sigla_UF", "Município"])

# %%
media_estoque_por_ano = media_estoque_por_ano.drop(columns=["Codigo do Municipio", "Município", "Sigla_UF"])

# %%
media_estoque_por_ano["Codigo_Municipio"] = media_estoque_por_ano["Codigo_Municipio"].astype(int)

# %%
media_estoque_por_ano = media_estoque_por_ano[['Codigo_Municipio'] + [col for col in media_estoque_por_ano.columns if col != 'Codigo_Municipio']]

# %%
media_estoque_por_ano
# Out:
#       Codigo_Municipio  UF                Municipio  2020_Estoque_media  \
# 0              1100015  RO    Alta Floresta D Oeste         1964.688688
# 1              1100379  RO  Alto Alegre dos Parecis          560.558275
# 2              1100403  RO             Alto Paraiso         1193.020182
# 3              1100346  RO         Alvorada D Oeste          807.904946
# 4              1100023  RO                Ariquemes        15949.639448
# ...                ...  ..                      ...                 ...
# 5565           5222005  GO               Vianopolis         2125.083615
# 5566           5222054  GO           Vicentinopolis         2367.003268
# 5567           5222203  GO                 Vila Boa         1750.044171
# 5568           5222302  GO            Vila Propicio          936.625616
# 5569           5300108  DF                 Brasilia       827892.784174
#
#       2021_Estoque_media  2022_Estoque_media  2023_Estoque_media  \
# 0            2096.666667         2195.916667         2272.166667
# 1             589.250000          629.000000          675.416667
# 2            1240.500000         1266.166667         1277.000000
# 3             877.916667          901.666667          872.416667
# 4           16900.166667        18565.750000        19121.750000
# ...                  ...                 ...                 ...
# 5565         2346.416667         2642.583333         2833.583333
# 5566         2318.166667         2431.333333         2529.000000
# 5567         1787.250000         1858.583333         1785.000000
# 5568         1022.666667         1099.250000         1178.416667
# 5569       858208.166667       915232.500000       954068.333333
#
#       2024_Estoque_media
# 0                 2294.0
# 1                  692.0
# 2                 1247.0
# 3                  867.0
# 4                19150.0
# ...                  ...
# 5565              2972.0
# 5566              2311.5
# 5567              1410.0
# 5568              1146.0
# 5569            973895.5
#
# [5570 rows x 8 columns]

# %%
with pd.ExcelWriter("caged_Atualizado.xlsx") as writer: 
    media_estoque_por_ano.to_excel(writer, sheet_name="sheet 1",index=False)
