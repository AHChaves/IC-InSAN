# %%
import pandas as pd

# %%
# %run funcoes_gerais.ipynb

# %%
cod_municipios = pd.read_csv('../Código dos Municípios')

# %%
pib_Munic = pd.read_excel("../dataset/Economico/Renda e Desenvolvimento/PIB/PIB-Munic.xlsx")
pib_Munic_BD = pd.read_excel("../dataset/Economico/Renda e Desenvolvimento/PIB/PIB dos Municбpios - base de dados 2010-2021.xlsx")

# %%
PAM_2020 = pd.read_excel("../dataset/Producao Alimentar/Tipos de Alimento/PAM_2020.xlsx")

# %%
cempre = pd.read_excel("../dataset/Economico/Renda e Desenvolvimento/Renda Per Capta/Cempre_2020.xlsx")

# %% [markdown]
# # Analise

# %% [markdown]
# ### PAM

# %%
PAM_2020.head()
# Out:
#                     Município Abacate Abacaxi* Açaí Alfafa fenada  \
# 0  Alta Floresta D'Oeste (RO)       -      205    4           ...
# 1              Ariquemes (RO)       -      410   45           ...
# 2                 Cabixi (RO)       -       60    -           ...
# 3                 Cacoal (RO)       -     1850    -           ...
# 4             Cerejeiras (RO)       -      750    -           ...
#
#   Algodão arbóreo (em caroço) Algodão herbáceo (em caroço) Alho  \
# 0                           -                            -    -
# 1                           -                            -    -
# 2                           -                            -    -
# 3                           -                            -    -
# 4                           -                            -    -
#
#   Amendoim (em casca) Arroz (em casca)  ... Sisal ou agave (fibra)  \
# 0                   3              705  ...                      -
# 1                   -             1650  ...                      -
# 2                   1             1920  ...                      -
# 3                  15               90  ...                      -
# 4                  13             2000  ...                      -
#
#   Soja (em grão) Sorgo (em grão) Tangerina Tomate Trigo (em grão)  \
# 0           1350               -        14    350               -
# 1          25497               -        16     45               -
# 2          86772               -         -      -               -
# 3           3000               -        35    205               -
# 4         140760               -         -   1000               -
#
#   Triticale (em grão) Tungue (fruto seco) Urucum (semente) Uva
# 0                   -                   -               39   -
# 1                   -                   -                9   -
# 2                   -                   -               99   -
# 3                   -                   -               21   -
# 4                   -                   -               98   -
#
# [5 rows x 72 columns]

# %%
PAM_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5563 entries, 0 to 5562
# Data columns (total 72 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Município                     5563 non-null   object
#  1   Abacate                       5563 non-null   object
#  2   Abacaxi*                      5563 non-null   object
#  3   Açaí                          5563 non-null   object
#  4   Alfafa fenada                 5563 non-null   object
#  5   Algodão arbóreo (em caroço)   5563 non-null   object
#  6   Algodão herbáceo (em caroço)  5563 non-null   object
#  7   Alho                          5563 non-null   object
#  8   Amendoim (em casca)           5563 non-null   object
#  9   Arroz (em casca)              5563 non-null   object
#  10  Aveia (em grão)               5563 non-null   object
#  11  Azeitona                      5563 non-null   object
#  12  Banana (cacho)                5563 non-null   object
#  13  Batata-doce                   5563 non-null   object
#  14  Batata-inglesa                5563 non-null   object
#  15  Borracha (látex coagulado)    5563 non-null   object
#  16  Borracha (látex líquido)      5563 non-null   object
#  17  Cacau (em amêndoa)            5563 non-null   object
#  18  Café (em grão) Total          5563 non-null   object
#  19  Café (em grão) Arábica        5563 non-null   object
#  20  Café (em grão) Canephora      5563 non-null   object
#  21  Caju                          5563 non-null   object
#  22  Cana-de-açúcar                5563 non-null   object
#  23  Cana para forragem            5563 non-null   object
#  24  Caqui                         5563 non-null   object
#  25  Castanha de caju              5563 non-null   object
#  26  Cebola                        5563 non-null   object
#  27  Centeio (em grão)             5563 non-null   object
#  28  Cevada (em grão)              5563 non-null   object
#  29  Chá-da-índia (folha verde)    5563 non-null   object
#  30  Coco-da-baía*                 5563 non-null   object
#  31  Dendê (cacho de coco)         5563 non-null   object
#  32  Erva-mate (folha verde)       5563 non-null   object
#  33  Ervilha (em grão)             5563 non-null   object
#  34  Fava (em grão)                5563 non-null   object
#  35  Feijão (em grão)              5563 non-null   object
#  36  Figo                          5563 non-null   object
#  37  Fumo (em folha)               5563 non-null   object
#  38  Girassol (em grão)            5563 non-null   object
#  39  Goiaba                        5563 non-null   object
#  40  Guaraná (semente)             5563 non-null   object
#  41  Juta (fibra)                  5563 non-null   object
#  42  Laranja                       5563 non-null   object
#  43  Limão                         5563 non-null   object
#  44  Linho (semente)               5563 non-null   object
#  45  Maçã                          5563 non-null   object
#  46  Malva (fibra)                 5563 non-null   object
#  47  Mamão                         5563 non-null   object
#  48  Mamona (baga)                 5563 non-null   object
#  49  Mandioca                      5563 non-null   object
#  50  Manga                         5563 non-null   object
#  51  Maracujá                      5563 non-null   object
#  52  Marmelo                       5563 non-null   object
#  53  Melancia                      5563 non-null   object
#  54  Melão                         5563 non-null   object
#  55  Milho (em grão)               5563 non-null   object
#  56  Noz (fruto seco)              5563 non-null   object
#  57  Palmito                       5563 non-null   object
#  58  Pera                          5563 non-null   object
#  59  Pêssego                       5563 non-null   object
#  60  Pimenta-do-reino              5563 non-null   object
#  61  Rami (fibra)                  5563 non-null   object
#  62  Sisal ou agave (fibra)        5563 non-null   object
#  63  Soja (em grão)                5563 non-null   object
#  64  Sorgo (em grão)               5563 non-null   object
#  65  Tangerina                     5563 non-null   object
#  66  Tomate                        5563 non-null   object
#  67  Trigo (em grão)               5563 non-null   object
#  68  Triticale (em grão)           5563 non-null   object
#  69  Tungue (fruto seco)           5563 non-null   object
#  70  Urucum (semente)              5563 non-null   object
#  71  Uva                           5563 non-null   object
# dtypes: object(72)
# memory usage: 3.1+ MB

# %% [markdown]
# ### PIB Munic

# %%
pib_Munic
# Out:
#          Cód.                   Município       2017       2018       2019  \
# 0     1100015  Alta Floresta D'Oeste (RO)     485374     498980     495775
# 1     1100023              Ariquemes (RO)    2287910    2464704    2579278
# 2     1100031                 Cabixi (RO)     138110     140503     139976
# 3     1100049                 Cacoal (RO)    2082761    2175840    2261930
# 4     1100056             Cerejeiras (RO)     439245     470647     506494
# ...       ...                         ...        ...        ...        ...
# 5565  5222005             Vianópolis (GO)     395861     449973     489265
# 5566  5222054         Vicentinópolis (GO)     350839     339089     326519
# 5567  5222203               Vila Boa (GO)     118639     108469     112209
# 5568  5222302          Vila Propício (GO)     182203     179915     207994
# 5569  5300108               Brasília (DF)  244722249  254817205  273613711
#
#            2020       2021
# 0        570242     734469
# 1       2817331    3209761
# 2        167153     238412
# 3       2518845    2792383
# 4        600630     743037
# ...         ...        ...
# 5565     559058     857968
# 5566     419757     480173
# 5567     126150     179899
# 5568     217935     308013
# 5569  265847334  286943782
#
# [5570 rows x 7 columns]

# %% [markdown]
# ### PIB Munic BD

# %%
pib_Munic_BD_2020 = pib_Munic_BD[pib_Munic_BD['Ano'] == 2020][['Código do Município', 'Produto Interno Bruto per capita, \na preços correntes\n(R$ 1,00)','Atividade com maior valor adicionado bruto']]

# %%
pib_Munic_BD_2020
# Out:
#        Código do Município  \
# 55685              1100015
# 55686              1100023
# 55687              1100031
# 55688              1100049
# 55689              1100056
# ...                    ...
# 61250              5222005
# 61251              5222054
# 61252              5222203
# 61253              5222302
# 61254              5300108
#
#        Produto Interno Bruto per capita, \na preços correntes\n(R$ 1,00)  \
# 55685                                           25089.83
# 55686                                           25723.65
# 55687                                           32219.13
# 55688                                           29325.38
# 55689                                           37066.80
# ...                                                  ...
# 61250                                           39998.43
# 61251                                           47307.22
# 61252                                           19985.71
# 61253                                           37051.24
# 61254                                           87016.16
#
#               Atividade com maior valor adicionado bruto
# 55685  Administração, defesa, educação e saúde públic...
# 55686                                    Demais serviços
# 55687  Administração, defesa, educação e saúde públic...
# 55688                                    Demais serviços
# 55689  Comércio e reparação de veículos automotores e...
# ...                                                  ...
# 61250  Agricultura, inclusive apoio à agricultura e a...
# 61251  Agricultura, inclusive apoio à agricultura e a...
# 61252  Administração, defesa, educação e saúde públic...
# 61253  Agricultura, inclusive apoio à agricultura e a...
# 61254  Administração, defesa, educação e saúde públic...
#
# [5570 rows x 3 columns]

# %%
pib_Munic_BD_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5570 entries, 55685 to 61254
# Data columns (total 3 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Código do Município                                              5570 non-null   int64
#  1   Produto Interno Bruto per capita,
# a preços correntes
# (R$ 1,00)  5570 non-null   float64
#  2   Atividade com maior valor adicionado bruto                       5570 non-null   object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 174.1+ KB

# %% [markdown]
# ### CEMPRE

# %%
cempre
# Out:
#      Unidades da Federação                  Municípios  \
# 0                 Rondônia  Alta Floresta D'Oeste - RO
# 1                 Rondônia              Ariquemes - RO
# 2                 Rondônia                 Cabixi - RO
# 3                 Rondônia                 Cacoal - RO
# 4                 Rondônia             Cerejeiras - RO
# ...                    ...                         ...
# 5565                 Goiás             Vianópolis - GO
# 5566                 Goiás         Vicentinópolis - GO
# 5567                 Goiás               Vila Boa - GO
# 5568                 Goiás          Vila Propício - GO
# 5569      Distrito Federal               Brasília - DF
#
#       Número de unidades\nlocais  Pessoal ocupado Total  \
# 0                            482                   2990
# 1                           2720                  20139
# 2                             60                    616
# 3                           2539                  20132
# 4                            428                   2631
# ...                          ...                    ...
# 5565                         453                   2404
# 5566                         192                   2080
# 5567                          69                   1304
# 5568                         111                   1124
# 5569                      106009                1372180
#
#       Pessoal ocupado Assalariado  Pessoal assalariado médio  \
# 0                            2378                    2368.93
# 1                           16743                   16290.27
# 2                             555                     566.61
# 3                           16660                   16814.82
# 4                            2117                    2056.84
# ...                           ...                        ...
# 5565                         1967                    1972.95
# 5566                         1861                    2210.76
# 5567                         1245                    1349.73
# 5568                          995                    1016.20
# 5569                      1246187                 1250059.13
#
#       Salários\ne outras\nremunerações\n(1 000 R$)  \
# 0                                     6.027268e+04
# 1                                     4.532944e+05
# 2                                     1.379010e+04
# 3                                     4.343149e+05
# 4                                     5.663793e+04
# ...                                            ...
# 5565                                  6.227452e+04
# 5566                                  6.414250e+04
# 5567                                  3.374652e+04
# 5568                                  2.287212e+04
# 5569                                  9.027115e+07
#
#       Salário médio\n mensal \n(salários mínimos)  (1) (2)   \
# 0                                              1.873702
# 1                                              2.049200
# 2                                              1.792320
# 3                                              1.902150
# 4                                              2.027865
# ...                                                 ...
# 5565                                           2.324484
# 5566                                           2.136665
# 5567                                           1.841257
# 5568                                           1.657522
# 5569                                           5.318028
#
#       Salário médio\n mensal \n(R$) (2)  Número de empresas atuantes
# 0                           1957.153684                          473
# 1                           2140.467795                         2622
# 2                           1872.147169                           59
# 3                           1986.868704                         2446
# 4                           2118.183008                          412
# ...                                 ...                          ...
# 5565                        2428.012679                          449
# 5566                        2231.829117                          192
# 5567                        1923.263456                           69
# 5568                        1731.345662                          105
# 5569                        5554.884758                        99473
#
# [5570 rows x 10 columns]

# %%
cempre.columns
# Out:
# Index(['Unidades da Federação', 'Municípios', 'Número de unidades\nlocais',
#        'Pessoal ocupado Total', 'Pessoal ocupado Assalariado',
#        'Pessoal assalariado médio',
#        'Salários\ne outras\nremunerações\n(1 000 R$)',
#        'Salário médio\n mensal \n(salários mínimos)  (1) (2) ',
#        'Salário médio\n mensal \n(R$) (2)', 'Número de empresas atuantes'],
#       dtype='object')

# %%
cempre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 10 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Unidades da Federação                                5570 non-null   object
#  1   Municípios                                           5570 non-null   object
#  2   Número de unidades
# locais                            5570 non-null   int64
#  3   Pessoal ocupado Total                                5570 non-null   int64
#  4   Pessoal ocupado Assalariado                          5570 non-null   int64
#  5   Pessoal assalariado médio                            5570 non-null   float64
#  6   Salários
# e outras
# remunerações
# (1 000 R$)            5570 non-null   float64
#  7   Salário médio
#  mensal
# (salários mínimos)  (1) (2)   5570 non-null   float64
#  8   Salário médio
#  mensal
# (R$) (2)                      5570 non-null   float64
#  9   Número de empresas atuantes                          5570 non-null   int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 435.3+ KB

# %% [markdown]
# # Transformação

# %% [markdown]
# ### PAM

# %%
PAM_2020 = PAM(PAM_2020)

# %%
PAM_2020
# Out:
#       Codigo_Municipio Produção de Abacate(toneladas)  \
# 0              1100015                              -
# 1              1100379                              -
# 2              1100403                              -
# 3              1100346                              -
# 4              1100023                              -
# ...                ...                            ...
# 5565           5222005                              -
# 5566           5222054                              -
# 5567           5222203                              -
# 5568           5222302                              -
# 5569           5300108                           2850
#
#      Produção de Abacaxi*(toneladas) Produção de Açaí(toneladas)  \
# 0                                205                           4
# 1                                 50                          15
# 2                                600                          90
# 3                                 78                           -
# 4                                410                          45
# ...                              ...                         ...
# 5565                               -                           -
# 5566                               -                           -
# 5567                               -                           -
# 5568                               -                           -
# 5569                             198                           -
#
#      Produção de Alfafa fenada(toneladas)  \
# 0                                     ...
# 1                                     ...
# 2                                     ...
# 3                                     ...
# 4                                     ...
# ...                                   ...
# 5565                                  ...
# 5566                                  ...
# 5567                                  ...
# 5568                                  ...
# 5569                                  ...
#
#      Produção de Algodão arbóreo (em caroço)(toneladas)  \
# 0                                                     -
# 1                                                     -
# 2                                                     -
# 3                                                     -
# 4                                                     -
# ...                                                 ...
# 5565                                                  -
# 5566                                                  -
# 5567                                                  -
# 5568                                                  -
# 5569                                                  -
#
#      Produção de Algodão herbáceo (em caroço)(toneladas)  \
# 0                                                     -
# 1                                                     -
# 2                                                     -
# 3                                                     -
# 4                                                     -
# ...                                                 ...
# 5565                                                  -
# 5566                                                  -
# 5567                                                  -
# 5568                                                  -
# 5569                                                  -
#
#      Produção de Alho(toneladas) Produção de Amendoim (em casca)(toneladas)  \
# 0                              -                                          3
# 1                              -                                         52
# 2                              -                                          5
# 3                              -                                          -
# 4                              -                                          -
# ...                          ...                                        ...
# 5565                           -                                          -
# 5566                           -                                          -
# 5567                           -                                          -
# 5568                           -                                          -
# 5569                        4800                                          -
#
#      Produção de Arroz (em casca)(toneladas)  ...  \
# 0                                        705  ...
# 1                                        480  ...
# 2                                       3300  ...
# 3                                        315  ...
# 4                                       1650  ...
# ...                                      ...  ...
# 5565                                       -  ...
# 5566                                       -  ...
# 5567                                       -  ...
# 5568                                      24  ...
# 5569                                       -  ...
#
#      Produção de Sisal ou agave (fibra)(toneladas)  \
# 0                                                -
# 1                                                -
# 2                                                -
# 3                                                -
# 4                                                -
# ...                                            ...
# 5565                                             -
# 5566                                             -
# 5567                                             -
# 5568                                             -
# 5569                                             -
#
#      Produção de Soja (em grão)(toneladas)  \
# 0                                     1350
# 1                                    10135
# 2                                    64052
# 3                                     1221
# 4                                    25497
# ...                                    ...
# 5565                                154980
# 5566                                 73500
# 5567                                   900
# 5568                                 45090
# 5569                                290550
#
#      Produção de Sorgo (em grão)(toneladas) Produção de Tangerina(toneladas)  \
# 0                                         -                               14
# 1                                         -                               14
# 2                                         -                                -
# 3                                         -                                -
# 4                                         -                               16
# ...                                     ...                              ...
# 5565                                  18000                                -
# 5566                                  22500                                -
# 5567                                   6500                                -
# 5568                                      -                                -
# 5569                                  48000                             2312
#
#      Produção de Tomate(toneladas) Produção de Trigo (em grão)(toneladas)  \
# 0                              350                                      -
# 1                              400                                      -
# 2                               90                                      -
# 3                              165                                      -
# 4                               45                                      -
# ...                            ...                                    ...
# 5565                         68367                                    855
# 5566                         25800                                      -
# 5567                             -                                      -
# 5568                          2850                                      -
# 5569                         28000                                  11400
#
#      Produção de Triticale (em grão)(toneladas)  \
# 0                                             -
# 1                                             -
# 2                                             -
# 3                                             -
# 4                                             -
# ...                                         ...
# 5565                                          -
# 5566                                          -
# 5567                                          -
# 5568                                          -
# 5569                                          -
#
#      Produção de Tungue (fruto seco)(toneladas)  \
# 0                                             -
# 1                                             -
# 2                                             -
# 3                                             -
# 4                                             -
# ...                                         ...
# 5565                                          -
# 5566                                          -
# 5567                                          -
# 5568                                          -
# 5569                                          -
#
#      Produção de Urucum (semente)(toneladas) Produção de Uva(toneladas)
# 0                                         39                          -
# 1                                          1                          -
# 2                                          5                          -
# 3                                          5                          -
# 4                                          9                          -
# ...                                      ...                        ...
# 5565                                       -                          -
# 5566                                       -                          -
# 5567                                       -                          -
# 5568                                       -                          -
# 5569                                       -                       1425
#
# [5570 rows x 72 columns]

# %% [markdown]
# ### PIB Munic BD

# %%
for col in pib_Munic.columns[2:]:
    pib_Munic[col] = pib_Munic[col].apply(lambda x: f"{x:,.1f}".replace(",", "X").replace(".", ",").replace("X", "."))

# %%
pib_Munic = pib_Munic.rename(columns={'Cód.':'Codigo_Municipio','2020':'PIB do Municipio'})

# %%
pib_Munic.head()
# Out:
#    Codigo_Municipio                   Município         2017         2018  \
# 0           1100015  Alta Floresta D'Oeste (RO)    485.374,0    498.980,0
# 1           1100023              Ariquemes (RO)  2.287.910,0  2.464.704,0
# 2           1100031                 Cabixi (RO)    138.110,0    140.503,0
# 3           1100049                 Cacoal (RO)  2.082.761,0  2.175.840,0
# 4           1100056             Cerejeiras (RO)    439.245,0    470.647,0
#
#           2019 PIB do Municipio         2021
# 0    495.775,0        570.242,0    734.469,0
# 1  2.579.278,0      2.817.331,0  3.209.761,0
# 2    139.976,0        167.153,0    238.412,0
# 3  2.261.930,0      2.518.845,0  2.792.383,0
# 4    506.494,0        600.630,0    743.037,0

# %% [markdown]
# ### PIB Munic BD

# %%
pib_Munic_BD_2020 = pib_Munic_BD_2020.rename(columns={'Código do Município': 'Codigo_Municipio', 
                        'Produto Interno Bruto per capita, \na preços correntes\n(R$ 1,00)': 'Produto Interno Bruto per capita, a preços correntes(R$ 1,00)'})
pib_Munic_BD_2020['Produto Interno Bruto per capita, a preços correntes(R$ 1,00)'] = pib_Munic_BD_2020['Produto Interno Bruto per capita, a preços correntes(R$ 1,00)'].apply(lambda x: f"{x:,.1f}".replace(",", "X").replace(".", ",").replace("X", "."))

# %%
pib_Munic_BD_2020
# Out:
#        Codigo_Municipio  \
# 55685           1100015
# 55686           1100023
# 55687           1100031
# 55688           1100049
# 55689           1100056
# ...                 ...
# 61250           5222005
# 61251           5222054
# 61252           5222203
# 61253           5222302
# 61254           5300108
#
#       Produto Interno Bruto per capita, a preços correntes(R$ 1,00)  \
# 55685                                           25.089,8
# 55686                                           25.723,7
# 55687                                           32.219,1
# 55688                                           29.325,4
# 55689                                           37.066,8
# ...                                                  ...
# 61250                                           39.998,4
# 61251                                           47.307,2
# 61252                                           19.985,7
# 61253                                           37.051,2
# 61254                                           87.016,2
#
#               Atividade com maior valor adicionado bruto
# 55685  Administração, defesa, educação e saúde públic...
# 55686                                    Demais serviços
# 55687  Administração, defesa, educação e saúde públic...
# 55688                                    Demais serviços
# 55689  Comércio e reparação de veículos automotores e...
# ...                                                  ...
# 61250  Agricultura, inclusive apoio à agricultura e a...
# 61251  Agricultura, inclusive apoio à agricultura e a...
# 61252  Administração, defesa, educação e saúde públic...
# 61253  Agricultura, inclusive apoio à agricultura e a...
# 61254  Administração, defesa, educação e saúde públic...
#
# [5570 rows x 3 columns]

# %% [markdown]
# ### CEMPRE

# %%
cempre = CEMPRE(cempre)

# %%
cempre
# Out:
#       Codigo_Municipio  Número de unidades\nlocais  Pessoal ocupado Total  \
# 0              1100015                       482.0                 2990.0
# 1              1100379                       146.0                 1100.0
# 2              1100403                       256.0                 1472.0
# 3              1100346                       252.0                 1541.0
# 4              1100023                      2720.0                20139.0
# ...                ...                         ...                    ...
# 5565           5222005                       453.0                 2404.0
# 5566           5222054                       192.0                 2080.0
# 5567           5222203                        69.0                 1304.0
# 5568           5222302                       111.0                 1124.0
# 5569           5300108                    106009.0              1372180.0
#
#       Pessoal ocupado Assalariado  Pessoal assalariado médio  \
# 0                          2378.0                    2368.93
# 1                           912.0                     905.13
# 2                          1151.0                    1207.64
# 3                          1238.0                    1220.07
# 4                         16743.0                   16290.27
# ...                           ...                        ...
# 5565                       1967.0                    1972.95
# 5566                       1861.0                    2210.76
# 5567                       1245.0                    1349.73
# 5568                        995.0                    1016.20
# 5569                    1246187.0                 1250059.13
#
#       Salários\ne outras\nremunerações\n(1 000 R$)  \
# 0                                     6.027268e+04
# 1                                     2.296176e+04
# 2                                     3.130146e+04
# 3                                     2.666324e+04
# 4                                     4.532944e+05
# ...                                            ...
# 5565                                  6.227452e+04
# 5566                                  6.414250e+04
# 5567                                  3.374652e+04
# 5568                                  2.287212e+04
# 5569                                  9.027115e+07
#
#       Salário médio\n mensal \n(salários mínimos)  (1) (2)   \
# 0                                              1.873702
# 1                                              1.868213
# 2                                              1.908795
# 3                                              1.609387
# 4                                              2.049200
# ...                                                 ...
# 5565                                           2.324484
# 5566                                           2.136665
# 5567                                           1.841257
# 5568                                           1.657522
# 5569                                           5.318028
#
#      Salário médio mensal(R$)  Número de empresas atuantes
# 0                     1.957,2                        473.0
# 1                     1.951,4                        146.0
# 2                     1.993,8                        255.0
# 3                     1.681,1                        246.0
# 4                     2.140,5                       2622.0
# ...                       ...                          ...
# 5565                  2.428,0                        449.0
# 5566                  2.231,8                        192.0
# 5567                  1.923,3                         69.0
# 5568                  1.731,3                        105.0
# 5569                  5.554,9                      99473.0
#
# [5570 rows x 9 columns]

# %% [markdown]
# # Integração

# %%
bd_2020 = cod_municipios[['Codigo_Municipio', 'Município', 'UF', 'Sigla_UF']]

# %%
bd_2020 = bd_2020.merge(pib_Munic[['Codigo_Municipio', 'PIB do Municipio']], how='right')

# %%
bd_2020 = bd_2020.merge(pib_Munic_BD_2020, how='right')

# %%
bd_2020 = bd_2020.merge(cempre[['Codigo_Municipio', 'Salário médio mensal(R$)']], how='right')

# %%
bd_2020 = bd_2020.merge(PAM_2020, how='right')

# %%
bd_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 79 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Codigo_Municipio                                               5570 non-null   int64
#  1   Município                                                      5570 non-null   object
#  2   UF                                                             5570 non-null   int64
#  3   Sigla_UF                                                       5570 non-null   object
#  4   PIB do Municipio                                               5570 non-null   object
#  5   Produto Interno Bruto per capita, a preços correntes(R$ 1,00)  5570 non-null   object
#  6   Atividade com maior valor adicionado bruto                     5570 non-null   object
#  7   Salário médio mensal(R$)                                       5570 non-null   object
#  8   Produção de Abacate(toneladas)                                 5563 non-null   object
#  9   Produção de Abacaxi*(toneladas)                                5563 non-null   object
#  10  Produção de Açaí(toneladas)                                    5563 non-null   object
#  11  Produção de Alfafa fenada(toneladas)                           5563 non-null   object
#  12  Produção de Algodão arbóreo (em caroço)(toneladas)             5563 non-null   object
#  13  Produção de Algodão herbáceo (em caroço)(toneladas)            5563 non-null   object
#  14  Produção de Alho(toneladas)                                    5563 non-null   object
#  15  Produção de Amendoim (em casca)(toneladas)                     5563 non-null   object
#  16  Produção de Arroz (em casca)(toneladas)                        5563 non-null   object
#  17  Produção de Aveia (em grão)(toneladas)                         5563 non-null   object
#  18  Produção de Azeitona(toneladas)                                5563 non-null   object
#  19  Produção de Banana (cacho)(toneladas)                          5563 non-null   object
#  20  Produção de Batata-doce(toneladas)                             5563 non-null   object
#  21  Produção de Batata-inglesa(toneladas)                          5563 non-null   object
#  22  Produção de Borracha (látex coagulado)(toneladas)              5563 non-null   object
#  23  Produção de Borracha (látex líquido)(toneladas)                5563 non-null   object
#  24  Produção de Cacau (em amêndoa)(toneladas)                      5563 non-null   object
#  25  Produção de Café (em grão) Total(toneladas)                    5563 non-null   object
#  26  Produção de Café (em grão) Arábica(toneladas)                  5563 non-null   object
#  27  Produção de Café (em grão) Canephora(toneladas)                5563 non-null   object
#  28  Produção de Caju(toneladas)                                    5563 non-null   object
#  29  Produção de Cana-de-açúcar(toneladas)                          5563 non-null   object
#  30  Produção de Cana para forragem(toneladas)                      5563 non-null   object
#  31  Produção de Caqui(toneladas)                                   5563 non-null   object
#  32  Produção de Castanha de caju(toneladas)                        5563 non-null   object
#  33  Produção de Cebola(toneladas)                                  5563 non-null   object
#  34  Produção de Centeio (em grão)(toneladas)                       5563 non-null   object
#  35  Produção de Cevada (em grão)(toneladas)                        5563 non-null   object
#  36  Produção de Chá-da-índia (folha verde)(toneladas)              5563 non-null   object
#  37  Produção de Coco-da-baía*(toneladas)                           5563 non-null   object
#  38  Produção de Dendê (cacho de coco)(toneladas)                   5563 non-null   object
#  39  Produção de Erva-mate (folha verde)(toneladas)                 5563 non-null   object
#  40  Produção de Ervilha (em grão)(toneladas)                       5563 non-null   object
#  41  Produção de Fava (em grão)(toneladas)                          5563 non-null   object
#  42  Produção de Feijão (em grão)(toneladas)                        5563 non-null   object
#  43  Produção de Figo(toneladas)                                    5563 non-null   object
#  44  Produção de Fumo (em folha)(toneladas)                         5563 non-null   object
#  45  Produção de Girassol (em grão)(toneladas)                      5563 non-null   object
#  46  Produção de Goiaba(toneladas)                                  5563 non-null   object
#  47  Produção de Guaraná (semente)(toneladas)                       5563 non-null   object
#  48  Produção de Juta (fibra)(toneladas)                            5563 non-null   object
#  49  Produção de Laranja(toneladas)                                 5563 non-null   object
#  50  Produção de Limão(toneladas)                                   5563 non-null   object
#  51  Produção de Linho (semente)(toneladas)                         5563 non-null   object
#  52  Produção de Maçã(toneladas)                                    5563 non-null   object
#  53  Produção de Malva (fibra)(toneladas)                           5563 non-null   object
#  54  Produção de Mamão(toneladas)                                   5563 non-null   object
#  55  Produção de Mamona (baga)(toneladas)                           5563 non-null   object
#  56  Produção de Mandioca(toneladas)                                5563 non-null   object
#  57  Produção de Manga(toneladas)                                   5563 non-null   object
#  58  Produção de Maracujá(toneladas)                                5563 non-null   object
#  59  Produção de Marmelo(toneladas)                                 5563 non-null   object
#  60  Produção de Melancia(toneladas)                                5563 non-null   object
#  61  Produção de Melão(toneladas)                                   5563 non-null   object
#  62  Produção de Milho (em grão)(toneladas)                         5563 non-null   object
#  63  Produção de Noz (fruto seco)(toneladas)                        5563 non-null   object
#  64  Produção de Palmito(toneladas)                                 5563 non-null   object
#  65  Produção de Pera(toneladas)                                    5563 non-null   object
#  66  Produção de Pêssego(toneladas)                                 5563 non-null   object
#  67  Produção de Pimenta-do-reino(toneladas)                        5563 non-null   object
#  68  Produção de Rami (fibra)(toneladas)                            5563 non-null   object
#  69  Produção de Sisal ou agave (fibra)(toneladas)                  5563 non-null   object
#  70  Produção de Soja (em grão)(toneladas)                          5563 non-null   object
#  71  Produção de Sorgo (em grão)(toneladas)                         5563 non-null   object
#  72  Produção de Tangerina(toneladas)                               5563 non-null   object
#  73  Produção de Tomate(toneladas)                                  5563 non-null   object
#  74  Produção de Trigo (em grão)(toneladas)                         5563 non-null   object
#  75  Produção de Triticale (em grão)(toneladas)                     5563 non-null   object
#  76  Produção de Tungue (fruto seco)(toneladas)                     5563 non-null   object
#  77  Produção de Urucum (semente)(toneladas)                        5563 non-null   object
#  78  Produção de Uva(toneladas)                                     5563 non-null   object
# dtypes: int64(2), object(77)
# memory usage: 3.4+ MB

# %%
bd_2020
# Out:
#       Codigo_Municipio                Município  UF Sigla_UF PIB do Municipio  \
# 0              1100015    Alta Floresta D'Oeste  11       RO        570.242,0
# 1              1100379  Alto Alegre dos Parecis  11       RO        324.519,0
# 2              1100403             Alto Paraíso  11       RO        396.387,0
# 3              1100346         Alvorada D'Oeste  11       RO        289.497,0
# 4              1100023                Ariquemes  11       RO      2.817.331,0
# ...                ...                      ...  ..      ...              ...
# 5565           5222005               Vianópolis  52       GO        559.058,0
# 5566           5222054           Vicentinópolis  52       GO        419.757,0
# 5567           5222203                 Vila Boa  52       GO        126.150,0
# 5568           5222302            Vila Propício  52       GO        217.935,0
# 5569           5300108                 Brasília  53       DF    265.847.334,0
#
#      Produto Interno Bruto per capita, a preços correntes(R$ 1,00)  \
# 0                                              25.089,8
# 1                                              24.482,7
# 2                                              18.143,8
# 3                                              20.523,0
# 4                                              25.723,7
# ...                                                 ...
# 5565                                           39.998,4
# 5566                                           47.307,2
# 5567                                           19.985,7
# 5568                                           37.051,2
# 5569                                           87.016,2
#
#              Atividade com maior valor adicionado bruto  \
# 0     Administração, defesa, educação e saúde públic...
# 1     Agricultura, inclusive apoio à agricultura e a...
# 2     Administração, defesa, educação e saúde públic...
# 3     Administração, defesa, educação e saúde públic...
# 4                                       Demais serviços
# ...                                                 ...
# 5565  Agricultura, inclusive apoio à agricultura e a...
# 5566  Agricultura, inclusive apoio à agricultura e a...
# 5567  Administração, defesa, educação e saúde públic...
# 5568  Agricultura, inclusive apoio à agricultura e a...
# 5569  Administração, defesa, educação e saúde públic...
#
#      Salário médio mensal(R$) Produção de Abacate(toneladas)  \
# 0                     1.957,2                              -
# 1                     1.951,4                              -
# 2                     1.993,8                              -
# 3                     1.681,1                              -
# 4                     2.140,5                              -
# ...                       ...                            ...
# 5565                  2.428,0                              -
# 5566                  2.231,8                              -
# 5567                  1.923,3                              -
# 5568                  1.731,3                              -
# 5569                  5.554,9                           2850
#
#      Produção de Abacaxi*(toneladas)  ...  \
# 0                                205  ...
# 1                                 50  ...
# 2                                600  ...
# 3                                 78  ...
# 4                                410  ...
# ...                              ...  ...
# 5565                               -  ...
# 5566                               -  ...
# 5567                               -  ...
# 5568                               -  ...
# 5569                             198  ...
#
#      Produção de Sisal ou agave (fibra)(toneladas)  \
# 0                                                -
# 1                                                -
# 2                                                -
# 3                                                -
# 4                                                -
# ...                                            ...
# 5565                                             -
# 5566                                             -
# 5567                                             -
# 5568                                             -
# 5569                                             -
#
#      Produção de Soja (em grão)(toneladas)  \
# 0                                     1350
# 1                                    10135
# 2                                    64052
# 3                                     1221
# 4                                    25497
# ...                                    ...
# 5565                                154980
# 5566                                 73500
# 5567                                   900
# 5568                                 45090
# 5569                                290550
#
#      Produção de Sorgo (em grão)(toneladas) Produção de Tangerina(toneladas)  \
# 0                                         -                               14
# 1                                         -                               14
# 2                                         -                                -
# 3                                         -                                -
# 4                                         -                               16
# ...                                     ...                              ...
# 5565                                  18000                                -
# 5566                                  22500                                -
# 5567                                   6500                                -
# 5568                                      -                                -
# 5569                                  48000                             2312
#
#      Produção de Tomate(toneladas) Produção de Trigo (em grão)(toneladas)  \
# 0                              350                                      -
# 1                              400                                      -
# 2                               90                                      -
# 3                              165                                      -
# 4                               45                                      -
# ...                            ...                                    ...
# 5565                         68367                                    855
# 5566                         25800                                      -
# 5567                             -                                      -
# 5568                          2850                                      -
# 5569                         28000                                  11400
#
#      Produção de Triticale (em grão)(toneladas)  \
# 0                                             -
# 1                                             -
# 2                                             -
# 3                                             -
# 4                                             -
# ...                                         ...
# 5565                                          -
# 5566                                          -
# 5567                                          -
# 5568                                          -
# 5569                                          -
#
#      Produção de Tungue (fruto seco)(toneladas)  \
# 0                                             -
# 1                                             -
# 2                                             -
# 3                                             -
# 4                                             -
# ...                                         ...
# 5565                                          -
# 5566                                          -
# 5567                                          -
# 5568                                          -
# 5569                                          -
#
#      Produção de Urucum (semente)(toneladas) Produção de Uva(toneladas)
# 0                                         39                          -
# 1                                          1                          -
# 2                                          5                          -
# 3                                          5                          -
# 4                                          9                          -
# ...                                      ...                        ...
# 5565                                       -                          -
# 5566                                       -                          -
# 5567                                       -                          -
# 5568                                       -                          -
# 5569                                       -                       1425
#
# [5570 rows x 79 columns]
