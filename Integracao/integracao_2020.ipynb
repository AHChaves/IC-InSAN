# %%
import pandas as pd

# %%
# %run funcoes_gerais.ipynb

# %%
cod_municipios = pd.read_csv('../dataset/Código dos Municípios')

# %%
caged = pd.read_excel("../dataset/Economico/Renda e Desenvolvimento/PIB/caged_Atualizado.xlsx")

# %%
bolsa_familia = pd.read_csv("../dataset/Social/Projetos Sociais/Bolsa_Familia_2020.csv")
bpc = pd.read_csv("../dataset/Social/Projetos Sociais/bpc_2020.csv")

# %%
pib_Munic = pd.read_excel("../dataset/Economico/Renda e Desenvolvimento/PIB/PIB-Munic.xlsx")
pib_Munic_BD = pd.read_excel("../dataset/Economico/Renda e Desenvolvimento/PIB/PIB dos Municбpios - base de dados 2010-2021.xlsx")

# %%
PAM_2020 = pd.read_excel("../dataset/Producao Alimentar/Tipos de Alimento/PAM_2020.xlsx")

# %%
cempre = pd.read_excel("../dataset/Economico/Renda e Desenvolvimento/Renda Per Capta/Cempre_2020.xlsx")

# %% [markdown]
# # Analise

# %% [markdown]
# ### Caged

# %%
caged
# Out:
#       Codigo_Municipio  Codigo_Municipio_2  UF                Municipio  \
# 0              1100015              110001  RO    Alta Floresta D Oeste
# 1              1100379              110037  RO  Alto Alegre dos Parecis
# 2              1100403              110040  RO             Alto Paraiso
# 3              1100346              110034  RO         Alvorada D Oeste
# 4              1100023              110002  RO                Ariquemes
# ...                ...                 ...  ..                      ...
# 5565           5222005              522200  GO               Vianopolis
# 5566           5222054              522205  GO           Vicentinopolis
# 5567           5222203              522220  GO                 Vila Boa
# 5568           5222302              522230  GO            Vila Propicio
# 5569           5300108              530010  DF                 Brasilia
#
#       2020_Estoque_media  2020_Estoque_MAX  2020_Estoque_MIN  \
# ...

# %%
caged = caged[['Codigo_Municipio', '2020_Estoque_media', '2020_Estoque_MAX', '2020_Estoque_MIN']]

# %%
caged
# Out:
#       Codigo_Municipio  2020_Estoque_media  2020_Estoque_MAX  2020_Estoque_MIN
# 0              1100015            1,964.69          2,024.00          1,915.00
# 1              1100379              560.56            576.00            549.00
# 2              1100403            1,193.02          1,233.00          1,165.00
# 3              1100346              807.90            827.00            785.00
# 4              1100023           15,949.64         16,308.00         15,508.00
# ...                ...                 ...               ...               ...
# 5565           5222005            2,125.08          2,171.00          2,091.00
# 5566           5222054            2,367.00          2,549.00          2,052.00
# 5567           5222203            1,750.04          2,052.00          1,524.00
# 5568           5222302              936.63            956.00            914.00
# 5569           5300108          827,892.78        847,945.00        814,709.00
#
# [5570 rows x 4 columns]

# %% [markdown]
# ### PAM

# %%
PAM_2020.head()
# Out:
#                     Município Abacate Abacaxi* Açaí Alfafa fenada  \
# 0  Alta Floresta D'Oeste (RO)       -      205    4           ...
# 1              Ariquemes (RO)       -      410   45           ...
# 2                 Cabixi (RO)       -       60    -           ...
# 3                 Cacoal (RO)       -     1850    -           ...
# 4             Cerejeiras (RO)       -      750    -           ...
#
#   Algodão arbóreo (em caroço) Algodão herbáceo (em caroço) Alho  \
# 0                           -                            -    -
# 1                           -                            -    -
# 2                           -                            -    -
# 3                           -                            -    -
# 4                           -                            -    -
#
#   Amendoim (em casca) Arroz (em casca)  ... Sisal ou agave (fibra)  \
# 0                   3              705  ...                      -
# ...

# %%
PAM_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5563 entries, 0 to 5562
# Data columns (total 72 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Município                     5563 non-null   object
#  1   Abacate                       5563 non-null   object
#  2   Abacaxi*                      5563 non-null   object
#  3   Açaí                          5563 non-null   object
#  4   Alfafa fenada                 5563 non-null   object
#  5   Algodão arbóreo (em caroço)   5563 non-null   object
#  6   Algodão herbáceo (em caroço)  5563 non-null   object
#  7   Alho                          5563 non-null   object
#  8   Amendoim (em casca)           5563 non-null   object
#  9   Arroz (em casca)              5563 non-null   object
#  10  Aveia (em grão)               5563 non-null   object
#  11  Azeitona                      5563 non-null   object
# ...

# %% [markdown]
# ### PIB Munic

# %%
pib_Munic
# Out:
#          Cód.                   Município       2017       2018       2019  \
# 0     1100015  Alta Floresta D'Oeste (RO)     485374     498980     495775
# 1     1100023              Ariquemes (RO)    2287910    2464704    2579278
# 2     1100031                 Cabixi (RO)     138110     140503     139976
# 3     1100049                 Cacoal (RO)    2082761    2175840    2261930
# 4     1100056             Cerejeiras (RO)     439245     470647     506494
# ...       ...                         ...        ...        ...        ...
# 5565  5222005             Vianópolis (GO)     395861     449973     489265
# 5566  5222054         Vicentinópolis (GO)     350839     339089     326519
# 5567  5222203               Vila Boa (GO)     118639     108469     112209
# 5568  5222302          Vila Propício (GO)     182203     179915     207994
# 5569  5300108               Brasília (DF)  244722249  254817205  273613711
#
#            2020       2021
# 0        570242     734469
# ...

# %% [markdown]
# ### PIB Munic BD

# %%
pib_Munic_BD[pib_Munic_BD['Ano'] == 2020]
# Out:
#         Ano  Código da Grande Região Nome da Grande Região  \
# 55685  2020                        1                 Norte
# 55686  2020                        1                 Norte
# 55687  2020                        1                 Norte
# 55688  2020                        1                 Norte
# 55689  2020                        1                 Norte
# ...     ...                      ...                   ...
# 61250  2020                        5          Centro-oeste
# 61251  2020                        5          Centro-oeste
# 61252  2020                        5          Centro-oeste
# 61253  2020                        5          Centro-oeste
# 61254  2020                        5          Centro-oeste
#
#        Código da Unidade da Federação Sigla da Unidade da Federação  \
# 55685                              11                            RO
# 55686                              11                            RO
# ...

# %%
pib_Munic_BD[pib_Munic_BD['Ano'] == 2020].columns
# Out:
# Index(['Ano', 'Código da Grande Região', 'Nome da Grande Região',
#        'Código da Unidade da Federação', 'Sigla da Unidade da Federação',
#        'Nome da Unidade da Federação', 'Código do Município',
#        'Nome do Município', 'Região Metropolitana', 'Código da Mesorregião',
#        'Nome da Mesorregião', 'Código da Microrregião', 'Nome da Microrregião',
#        'Código da Região Geográfica Imediata',
#        'Nome da Região Geográfica Imediata',
#        'Município da Região Geográfica Imediata',
#        'Código da Região Geográfica Intermediária',
#        'Nome da Região Geográfica Intermediária',
#        'Município da Região Geográfica Intermediária',
#        'Código Concentração Urbana', 'Nome Concentração Urbana',
#        'Tipo Concentração Urbana', 'Código Arranjo Populacional',
#        'Nome Arranjo Populacional', 'Hierarquia Urbana',
#        'Hierarquia Urbana (principais categorias)', 'Código da Região Rural',
#        'Nome da Região Rural',
# ...

# %%
pib_Munic_BD_2020 = pib_Munic_BD[pib_Munic_BD['Ano'] == 2020][['Código do Município', 'Produto Interno Bruto per capita, \na preços correntes\n(R$ 1,00)','Atividade com maior valor adicionado bruto']]

# %%
pib_Munic_BD_2020
# Out:
#        Código do Município  \
# 55685              1100015
# 55686              1100023
# 55687              1100031
# 55688              1100049
# 55689              1100056
# ...                    ...
# 61250              5222005
# 61251              5222054
# 61252              5222203
# 61253              5222302
# 61254              5300108
#
#        Produto Interno Bruto per capita, \na preços correntes\n(R$ 1,00)  \
# 55685                                          25,089.83
# 55686                                          25,723.65
# 55687                                          32,219.13
# 55688                                          29,325.38
# 55689                                          37,066.80
# ...                                                  ...
# 61250                                          39,998.43
# 61251                                          47,307.22
# 61252                                          19,985.71
# ...

# %%
pib_Munic_BD_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5570 entries, 55685 to 61254
# Data columns (total 3 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Código do Município                                              5570 non-null   int64
#  1   Produto Interno Bruto per capita,
# a preços correntes
# (R$ 1,00)  5570 non-null   float64
#  2   Atividade com maior valor adicionado bruto                       5570 non-null   object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 174.1+ KB

# %% [markdown]
# ### CEMPRE

# %%
cempre
# Out:
#      Unidades da Federação                  Municípios  \
# 0                 Rondônia  Alta Floresta D'Oeste - RO
# 1                 Rondônia              Ariquemes - RO
# 2                 Rondônia                 Cabixi - RO
# 3                 Rondônia                 Cacoal - RO
# 4                 Rondônia             Cerejeiras - RO
# ...                    ...                         ...
# 5565                 Goiás             Vianópolis - GO
# 5566                 Goiás         Vicentinópolis - GO
# 5567                 Goiás               Vila Boa - GO
# 5568                 Goiás          Vila Propício - GO
# 5569      Distrito Federal               Brasília - DF
#
#       Número de unidades\nlocais  Pessoal ocupado Total  \
# 0                            482                   2990
# 1                           2720                  20139
# 2                             60                    616
# 3                           2539                  20132
# ...

# %%
cempre.columns
# Out:
# Index(['Unidades da Federação', 'Municípios', 'Número de unidades\nlocais',
#        'Pessoal ocupado Total', 'Pessoal ocupado Assalariado',
#        'Pessoal assalariado médio',
#        'Salários\ne outras\nremunerações\n(1 000 R$)',
#        'Salário médio\n mensal \n(salários mínimos)  (1) (2) ',
#        'Salário médio\n mensal \n(R$) (2)', 'Número de empresas atuantes'],
#       dtype='object')

# %%
cempre.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 10 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Unidades da Federação                                5570 non-null   object
#  1   Municípios                                           5570 non-null   object
#  2   Número de unidades
# locais                            5570 non-null   int64
#  3   Pessoal ocupado Total                                5570 non-null   int64
#  4   Pessoal ocupado Assalariado                          5570 non-null   int64
#  5   Pessoal assalariado médio                            5570 non-null   float64
#  6   Salários
# e outras
# remunerações
# (1 000 R$)            5570 non-null   float64
#  7   Salário médio
#  mensal
# (salários mínimos)  (1) (2)   5570 non-null   float64
#  8   Salário médio
#  mensal
# ...

# %% [markdown]
# ### Bolsa Familia

# %%
bolsa_familia
# Out:
#          ibge  anomes  qtd_familias_beneficiarias_bolsa_familia  \
# 0      110001  202001                                      1521
# 1      110002  202001                                      3626
# 2      110003  202001                                       180
# 3      110004  202001                                      2970
# 4      110005  202001                                       686
# ...       ...     ...                                       ...
# 66835  522200  202012                                       392
# 66836  522205  202012                                       787
# 66837  522220  202012                                       552
# 66838  522230  202012                                       536
# 66839  530010  202012                                     83939
#
#        valor_repassado_bolsa_familia
# 0                         232,541.00
# 1                         518,218.00
# 2                          25,892.00
# 3                         465,018.00
# ...

# %%
bolsa_familia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66840 entries, 0 to 66839
# Data columns (total 4 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   ibge                                      66840 non-null  int64
#  1   anomes                                    66840 non-null  int64
#  2   qtd_familias_beneficiarias_bolsa_familia  66840 non-null  int64
#  3   valor_repassado_bolsa_familia             66840 non-null  float64
# dtypes: float64(1), int64(3)
# memory usage: 2.0 MB

# %%
bolsa_familia['anomes'].value_counts()
# Out:
# anomes
# 202001    5570
# 202002    5570
# 202003    5570
# 202004    5570
# 202005    5570
# 202006    5570
# 202007    5570
# 202008    5570
# 202009    5570
# 202010    5570
# 202011    5570
# 202012    5570
# Name: count, dtype: int64

# %% [markdown]
# ### BPC

# %%
bpc
# Out:
#          ibge  anomes  bpc_ben  bpc_pcd_ben  bpc_idoso_ben   bpc_pcd_val  \
# 0      110001  202001      503       402.00         101.00    418,717.00
# 1      110002  202001     2753     1,692.00       1,061.00  1,760,069.21
# 2      110003  202001       87        73.00          14.00     75,847.00
# 3      110004  202001     1989     1,297.00         692.00  1,347,585.88
# 4      110005  202001      445       355.00          90.00    369,885.48
# ...       ...     ...      ...          ...            ...           ...
# 66835  522200  202012      301       179.00         122.00    187,055.00
# 66836  522205  202012      139        93.00          46.00     97,185.00
# 66837  522220  202012      146       107.00          39.00    111,815.00
# 66838  522230  202012       33        24.00           9.00     25,080.00
# 66839  530010  202012    53913    27,164.00      26,749.00 28,413,983.27
#
#        bpc_idoso_val       bpc_val
# 0         104,939.78    523,656.78
# ...

# %%
bpc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66840 entries, 0 to 66839
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ibge           66840 non-null  int64
#  1   anomes         66840 non-null  int64
#  2   bpc_ben        66840 non-null  int64
#  3   bpc_pcd_ben    66789 non-null  float64
#  4   bpc_idoso_ben  66789 non-null  float64
#  5   bpc_pcd_val    66789 non-null  float64
#  6   bpc_idoso_val  66789 non-null  float64
#  7   bpc_val        66840 non-null  float64
# dtypes: float64(5), int64(3)
# memory usage: 4.1 MB

# %%
bpc['anomes'].value_counts()
# Out:
# anomes
# 202001    5570
# 202002    5570
# 202003    5570
# 202004    5570
# 202005    5570
# 202006    5570
# 202007    5570
# 202008    5570
# 202009    5570
# 202010    5570
# 202011    5570
# 202012    5570
# Name: count, dtype: int64

# %% [markdown]
# # Transformação

# %% [markdown]
# ### Caged

# %%
caged = caged.round(2)

# %%
caged
# Out:
#       Codigo_Municipio  2020_Estoque_media  2020_Estoque_MAX  2020_Estoque_MIN
# 0              1100015            1,964.69          2,024.00          1,915.00
# 1              1100379              560.56            576.00            549.00
# 2              1100403            1,193.02          1,233.00          1,165.00
# 3              1100346              807.90            827.00            785.00
# 4              1100023           15,949.64         16,308.00         15,508.00
# ...                ...                 ...               ...               ...
# 5565           5222005            2,125.08          2,171.00          2,091.00
# 5566           5222054            2,367.00          2,549.00          2,052.00
# 5567           5222203            1,750.04          2,052.00          1,524.00
# 5568           5222302              936.63            956.00            914.00
# 5569           5300108          827,892.78        847,945.00        814,709.00
#
# [5570 rows x 4 columns]

# %% [markdown]
# ### PAM

# %%
PAM_2020 = PAM(PAM_2020)

# %%
PAM_2020
# Out:
#       Codigo_Municipio Produção de Abacate(toneladas)  \
# 0              1100015                              -
# 1              1100379                              -
# 2              1100403                              -
# 3              1100346                              -
# 4              1100023                              -
# ...                ...                            ...
# 5565           5222005                              -
# 5566           5222054                              -
# 5567           5222203                              -
# 5568           5222302                              -
# 5569           5300108                           2850
#
#      Produção de Abacaxi*(toneladas) Produção de Açaí(toneladas)  \
# 0                                205                           4
# 1                                 50                          15
# 2                                600                          90
# ...

# %% [markdown]
# ### PIB Munic BD

# %%
# for col in pib_Munic.columns[2:]:
#     pib_Munic[col] = pib_Munic[col].apply(lambda x: f"{x:,.1f}".replace(",", "X").replace(".", ",").replace("X", "."))
pib_Munic = pib_Munic.round(2)

# %%
pib_Munic = pib_Munic.rename(columns={'Cód.':'Codigo_Municipio','2020':'PIB do Municipio'})

# %%
pib_Munic.head()
# Out:
#    Codigo_Municipio                   Município     2017     2018     2019  \
# 0           1100015  Alta Floresta D'Oeste (RO)   485374   498980   495775
# 1           1100023              Ariquemes (RO)  2287910  2464704  2579278
# 2           1100031                 Cabixi (RO)   138110   140503   139976
# 3           1100049                 Cacoal (RO)  2082761  2175840  2261930
# 4           1100056             Cerejeiras (RO)   439245   470647   506494
#
#    PIB do Municipio     2021
# 0            570242   734469
# 1           2817331  3209761
# 2            167153   238412
# 3           2518845  2792383
# 4            600630   743037

# %% [markdown]
# ### PIB Munic BD

# %%
pib_Munic_BD_2020 = pib_Munic_BD_2020.rename(columns={'Código do Município': 'Codigo_Municipio', 
                        'Produto Interno Bruto per capita, \na preços correntes\n(R$ 1,00)': 'Produto Interno Bruto per capita, a preços correntes(R$ 1,00)'})
# pib_Munic_BD_2020['Produto Interno Bruto per capita, a preços correntes(R$ 1,00)'] = pib_Munic_BD_2020['Produto Interno Bruto per capita, a preços correntes(R$ 1,00)'].apply(lambda x: f"{x:,.1f}".replace(",", "X").replace(".", ",").replace("X", "."))
pib_Munic_BD_2020 = pib_Munic_BD_2020.round(2)

# %%
pib_Munic_BD_2020
# Out:
#        Codigo_Municipio  \
# 55685           1100015
# 55686           1100023
# 55687           1100031
# 55688           1100049
# 55689           1100056
# ...                 ...
# 61250           5222005
# 61251           5222054
# 61252           5222203
# 61253           5222302
# 61254           5300108
#
#        Produto Interno Bruto per capita, a preços correntes(R$ 1,00)  \
# 55685                                          25,089.83
# 55686                                          25,723.65
# 55687                                          32,219.13
# 55688                                          29,325.38
# 55689                                          37,066.80
# ...                                                  ...
# 61250                                          39,998.43
# 61251                                          47,307.22
# 61252                                          19,985.71
# 61253                                          37,051.24
# ...

# %% [markdown]
# ### CEMPRE

# %%
cempre = CEMPRE(cempre)

# %%
cempre
# Out:
#       Codigo_Municipio  Número de unidades locais  Pessoal ocupado Total  \
# 0              1100015                     482.00               2,990.00
# 1              1100379                     146.00               1,100.00
# 2              1100403                     256.00               1,472.00
# 3              1100346                     252.00               1,541.00
# 4              1100023                   2,720.00              20,139.00
# ...                ...                        ...                    ...
# 5565           5222005                     453.00               2,404.00
# 5566           5222054                     192.00               2,080.00
# 5567           5222203                      69.00               1,304.00
# 5568           5222302                     111.00               1,124.00
# 5569           5300108                 106,009.00           1,372,180.00
#
#       Pessoal ocupado Assalariado  Pessoal assalariado médio  \
# ...

# %%
cempre.columns
# Out:
# Index(['Codigo_Municipio', 'Número de unidades locais',
#        'Pessoal ocupado Total', 'Pessoal ocupado Assalariado',
#        'Pessoal assalariado médio',
#        'Salário médio  mensal  (salários mínimos)  (1) (2) ',
#        'Salário médio mensal(R$)', 'Número de empresas atuantes'],
#       dtype='object')

# %% [markdown]
# ### Bolsa Familia

# %%
bolsa_familia = Bolsa_Familia(bolsa_familia)

# %%
bolsa_familia
# Out:
#         ibge  qtd_familias_total_bolsa_familia  \
# 0     110001                             18260
# 1     110002                             46484
# 2     110003                              2239
# 3     110004                             37130
# 4     110005                              8452
# ...      ...                               ...
# 5565  522200                              4600
# 5566  522205                              9491
# 5567  522220                              6441
# 5568  522230                              6278
# 5569  530010                            959537
#
#       media_qtd_familias_bolsa_familia  valor_total_repassado_bolsa_familia  \
# 0                             1,521.67                           791,541.00
# 1                             3,873.67                         2,040,617.00
# 2                               186.58                            90,412.00
# 3                             3,094.17                         1,927,489.00
# ...

# %% [markdown]
# ### BPC

# %%
bpc = BPC(bpc)

# %%
bpc
# Out:
#         ibge  num_beneficiados_bpc  media_beneficiados_bpc  \
# 0     110001                  6030                  502.50
# 1     110002                 33636                2,803.00
# 2     110003                  1017                   84.75
# 3     110004                 24134                2,011.17
# 4     110005                  5296                  441.33
# ...      ...                   ...                     ...
# 5565  522200                  3566                  297.17
# 5566  522205                  1717                  143.08
# 5567  522220                  1803                  150.25
# 5568  522230                   402                   33.50
# 5569  530010                650090               54,174.17
#
#       num_pcd_beneficiados_bpc  media_pcd_beneficiados_bpc  \
# 0                     4,821.00                      401.75
# 1                    20,759.00                    1,729.92
# 2                       848.00                       70.67
# ...

# %% [markdown]
# # Integração

# %%
bd_2020 = cod_municipios[['Codigo_Municipio', 'Codigo_Municipio_2', 'Município', 'UF', 'Sigla_UF']]

# %%
bd_2020 = bd_2020.merge(caged, how='left')

# %%
bd_2020 = bd_2020.merge(pib_Munic[['Codigo_Municipio', 'PIB do Municipio']], how='left')

# %%
bd_2020 = bd_2020.merge(pib_Munic_BD_2020, how='left')

# %%
bd_2020 = bd_2020.merge(cempre, how='left')

# %%
bd_2020 = bd_2020.merge(bolsa_familia, how='left', left_on='Codigo_Municipio_2', right_on='ibge')

# %%
bd_2020 = bd_2020.drop('ibge', axis=1)

# %%
bd_2020 = bd_2020.merge(bpc, how='left', left_on='Codigo_Municipio_2', right_on='ibge')

# %%
bd_2020 = bd_2020.drop('ibge', axis=1)

# %%
bd_2020 = bd_2020.merge(PAM_2020, how='left')

# %%
bd_2020.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Columns: 105 entries, Codigo_Municipio to Produção de Uva(toneladas)
# dtypes: float64(27), int64(4), object(74)
# memory usage: 4.5+ MB

# %%
bd_2020
# Out:
#       Codigo_Municipio  Codigo_Municipio_2                Município  UF  \
# 0              1100015              110001    Alta Floresta D'Oeste  11
# 1              1100379              110037  Alto Alegre dos Parecis  11
# 2              1100403              110040             Alto Paraíso  11
# 3              1100346              110034         Alvorada D'Oeste  11
# 4              1100023              110002                Ariquemes  11
# ...                ...                 ...                      ...  ..
# 5565           5222005              522200               Vianópolis  52
# 5566           5222054              522205           Vicentinópolis  52
# 5567           5222203              522220                 Vila Boa  52
# 5568           5222302              522230            Vila Propício  52
# 5569           5300108              530010                 Brasília  53
#
#      Sigla_UF  2020_Estoque_media  2020_Estoque_MAX  2020_Estoque_MIN  \
# ...

# %%
bd_2020.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 105 columns):
#  #    Column                                                         Non-Null Count  Dtype
# ---   ------                                                         --------------  -----
#  0    Codigo_Municipio                                               5570 non-null   int64
#  1    Codigo_Municipio_2                                             5570 non-null   int64
#  2    Município                                                      5570 non-null   object
#  3    UF                                                             5570 non-null   int64
#  4    Sigla_UF                                                       5570 non-null   object
#  5    2020_Estoque_media                                             5453 non-null   float64
#  6    2020_Estoque_MAX                                               5453 non-null   float64
# ...
