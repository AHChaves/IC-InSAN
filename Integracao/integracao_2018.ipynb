# %%
import pandas as pd

# %%
# %run funcoes_gerais.ipynb

# %%
PAM_2018 = pd.read_excel("../dataset/Producao Alimentar/Tipos de Alimento/PAM_2018.xlsx")

# %%
bolsa_familia = pd.read_csv("../dataset/Social/Projetos Sociais/Bolsa_Familia_2018.csv")
bpc = pd.read_csv("../dataset/Social/Projetos Sociais/bpc_2018.csv")

# %%
cod_municipios = pd.read_csv('../dataset/Código dos Municípios')

# %%
pib_Munic = pd.read_excel("../dataset/Economico/Renda e Desenvolvimento/PIB/PIB-Munic.xlsx")
pib_Munic_BD = pd.read_excel("../dataset/Economico/Renda e Desenvolvimento/PIB/PIB dos Municбpios - base de dados 2010-2021.xlsx")

# %% [markdown]
# # Analise

# %% [markdown]
# ### PIB Munic 2018

# %%
pib_Munic_BD_2018 = pib_Munic_BD[pib_Munic_BD['Ano'] == 2018][['Código do Município', 'Produto Interno Bruto per capita, \na preços correntes\n(R$ 1,00)','Atividade com maior valor adicionado bruto']]

# %%
pib_Munic_BD_2018.head()
# Out:
#        Código do Município  \
# 44545              1100015
# 44546              1100023
# 44547              1100031
# 44548              1100049
# 44549              1100056
#
#        Produto Interno Bruto per capita, \na preços correntes\n(R$ 1,00)  \
# 44545                                          21,538.40
# 44546                                          23,215.13
# 44547                                          25,837.30
# 44548                                          25,654.56
# 44549                                          28,621.22
#
#               Atividade com maior valor adicionado bruto
# 44545  Administração, defesa, educação e saúde públic...
# 44546                                    Demais serviços
# 44547  Administração, defesa, educação e saúde públic...
# 44548                                    Demais serviços
# 44549  Administração, defesa, educação e saúde públic...

# %%
pib_Munic_BD_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5570 entries, 44545 to 50114
# Data columns (total 3 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   Código do Município                                              5570 non-null   int64
#  1   Produto Interno Bruto per capita,
# a preços correntes
# (R$ 1,00)  5570 non-null   float64
#  2   Atividade com maior valor adicionado bruto                       5570 non-null   object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 174.1+ KB

# %% [markdown]
# ### Bolsa Familia

# %%
bolsa_familia.head()
# Out:
#      ibge  anomes  qtd_familias_beneficiarias_bolsa_familia  \
# 0  110001  201801                                      1594
# 1  110002  201801                                      4149
# 2  110003  201801                                       213
# 3  110004  201801                                      2536
# 4  110005  201801                                       682
#
#    valor_repassado_bolsa_familia
# 0                     248,748.00
# 1                     584,259.00
# 2                      28,617.00
# 3                     341,439.00
# 4                     100,676.00

# %%
bolsa_familia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66840 entries, 0 to 66839
# Data columns (total 4 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   ibge                                      66840 non-null  int64
#  1   anomes                                    66840 non-null  int64
#  2   qtd_familias_beneficiarias_bolsa_familia  66840 non-null  int64
#  3   valor_repassado_bolsa_familia             66840 non-null  float64
# dtypes: float64(1), int64(3)
# memory usage: 2.0 MB

# %%
bolsa_familia['anomes'].value_counts()
# Out:
# anomes
# 201801    5570
# 201802    5570
# 201803    5570
# 201804    5570
# 201805    5570
# 201806    5570
# 201807    5570
# 201808    5570
# 201809    5570
# 201810    5570
# 201811    5570
# 201812    5570
# Name: count, dtype: int64

# %% [markdown]
# ### BPC

# %%
bpc.head()
# Out:
#      ibge  anomes  bpc_ben  bpc_pcd_ben  bpc_idoso_ben  bpc_pcd_val  \
# 0  110001  201801      512          406            106   386,340.35
# 1  110002  201801     2774         1659           1115 1,580,806.19
# 2  110003  201801       94           74             20    70,596.00
# 3  110004  201801     1989         1265            724 1,203,909.02
# 4  110005  201801      434          349             85   332,660.00
#
#    bpc_idoso_val      bpc_val
# 0     100,478.96   486,819.31
# 1   1,062,803.49 2,643,609.68
# 2      19,080.00    89,676.00
# 3     690,400.26 1,894,309.28
# 4      81,080.46   413,740.46

# %%
bpc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66840 entries, 0 to 66839
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ibge           66840 non-null  int64
#  1   anomes         66840 non-null  int64
#  2   bpc_ben        66840 non-null  int64
#  3   bpc_pcd_ben    66840 non-null  int64
#  4   bpc_idoso_ben  66840 non-null  int64
#  5   bpc_pcd_val    66840 non-null  float64
#  6   bpc_idoso_val  66840 non-null  float64
#  7   bpc_val        66840 non-null  float64
# dtypes: float64(3), int64(5)
# memory usage: 4.1 MB

# %%
bpc['anomes'].value_counts()
# Out:
# anomes
# 201801    5570
# 201802    5570
# 201803    5570
# 201804    5570
# 201805    5570
# 201806    5570
# 201807    5570
# 201808    5570
# 201809    5570
# 201810    5570
# 201811    5570
# 201812    5570
# Name: count, dtype: int64

# %% [markdown]
# # Transformação

# %% [markdown]
# ### PIB Munic

# %%
# for col in pib_Munic.columns[2:]:
#     pib_Munic[col] = pib_Munic[col].apply(lambda x: f"{x:,.1f}".replace(",", "X").replace(".", ",").replace("X", "."))
pib_Munic = pib_Munic.round(2)

# %%
pib_Munic = pib_Munic.rename(columns={'Cód.':'Codigo_Municipio','2018':'PIB do Municipio'})

# %%
pib_Munic.head()
# Out:
#    Codigo_Municipio                   Município     2017  PIB do Municipio  \
# 0           1100015  Alta Floresta D'Oeste (RO)   485374            498980
# 1           1100023              Ariquemes (RO)  2287910           2464704
# 2           1100031                 Cabixi (RO)   138110            140503
# 3           1100049                 Cacoal (RO)  2082761           2175840
# 4           1100056             Cerejeiras (RO)   439245            470647
#
#       2019     2020     2021
# 0   495775   570242   734469
# 1  2579278  2817331  3209761
# 2   139976   167153   238412
# 3  2261930  2518845  2792383
# 4   506494   600630   743037

# %% [markdown]
# ### PIB Munic BD

# %%
pib_Munic_BD_2018 = pib_Munic_BD_2018.rename(columns={'Código do Município': 'Codigo_Municipio', 
                        'Produto Interno Bruto per capita, \na preços correntes\n(R$ 1,00)': 'Produto Interno Bruto per capita, a preços correntes(R$ 1,00)'})
pib_Munic_BD_2018 = pib_Munic_BD_2018.round(2)
# pib_Munic_BD_2018['Produto Interno Bruto per capita, a preços correntes(R$ 1,00)'] = pib_Munic_BD_2018['Produto Interno Bruto per capita, a preços correntes(R$ 1,00)'].apply(lambda x: f"{x:,.1f}".replace(",", "X").replace(".", ",").replace("X", "."))

# %%
pib_Munic_BD_2018.head()
# Out:
#        Codigo_Municipio  \
# 44545           1100015
# 44546           1100023
# 44547           1100031
# 44548           1100049
# 44549           1100056
#
#        Produto Interno Bruto per capita, a preços correntes(R$ 1,00)  \
# 44545                                          21,538.40
# 44546                                          23,215.13
# 44547                                          25,837.30
# 44548                                          25,654.56
# 44549                                          28,621.22
#
#               Atividade com maior valor adicionado bruto
# 44545  Administração, defesa, educação e saúde públic...
# 44546                                    Demais serviços
# 44547  Administração, defesa, educação e saúde públic...
# 44548                                    Demais serviços
# 44549  Administração, defesa, educação e saúde públic...

# %% [markdown]
# ### PAM

# %%
PAM_2018 = PAM(PAM_2018)

# %% [markdown]
# ### Bolsa Familia

# %%
bolsa_familia = Bolsa_Familia(bolsa_familia)

# %%
bolsa_familia
# Out:
#         ibge  qtd_familias_total_bolsa_familia  \
# 0     110001                             18402
# 1     110002                             48424
# 2     110003                              2403
# 3     110004                             31630
# 4     110005                              8233
# ...      ...                               ...
# 5565  522200                              5060
# 5566  522205                             10035
# 5567  522220                              7585
# 5568  522230                              7293
# 5569  530010                            917948
#
#       media_qtd_familias_bolsa_familia  valor_total_repassado_bolsa_familia  \
# 0                             1,533.50                         2,886,281.00
# 1                             4,035.33                         6,985,051.00
# 2                               200.25                           327,979.00
# 3                             2,635.83                         4,502,505.00
# 4                               686.08                         1,215,860.00
# ...                                ...                                  ...
# 5565                            421.67                           767,961.00
# 5566                            836.25                         1,656,334.00
# 5567                            632.08                         1,180,754.00
# 5568                            607.75                         1,071,589.00
# 5569                         76,495.67                       153,313,408.00
#
#       media_valor_repassado_bolsa_familia
# 0                              240,523.42
# 1                              582,087.58
# 2                               27,331.58
# 3                              375,208.75
# 4                              101,321.67
# ...                                   ...
# 5565                            63,996.75
# 5566                           138,027.83
# 5567                            98,396.17
# 5568                            89,299.08
# 5569                        12,776,117.33
#
# [5570 rows x 5 columns]

# %% [markdown]
# ### BPC

# %%
bpc = BPC(bpc)

# %%
bpc
# Out:
#         ibge  num_beneficiados_bpc  media_beneficiados_bpc  \
# 0     110001                  6226                  518.83
# 1     110002                 33482                2,790.17
# 2     110003                  1127                   93.92
# 3     110004                 24067                2,005.58
# 4     110005                  5285                  440.42
# ...      ...                   ...                     ...
# 5565  522200                  3604                  300.33
# 5566  522205                  1970                  164.17
# 5567  522220                  1948                  162.33
# 5568  522230                   371                   30.92
# 5569  530010                666779               55,564.92
#
#       num_pcd_beneficiados_bpc  media_pcd_beneficiados_bpc  \
# 0                         4929                      410.75
# 1                        20305                    1,692.08
# 2                          899                       74.92
# 3                        15497                    1,291.42
# 4                         4258                      354.83
# ...                        ...                         ...
# 5565                      2180                      181.67
# 5566                      1334                      111.17
# 5567                      1395                      116.25
# 5568                       302                       25.17
# 5569                    342669                   28,555.75
#
#       num_idoso_beneficiados_bpc  media_idoso_beneficiados_bpc  \
# 0                           1297                        108.08
# 1                          13177                      1,098.08
# 2                            228                         19.00
# 3                           8570                        714.17
# 4                           1027                         85.58
# ...                          ...                           ...
# 5565                        1424                        118.67
# 5566                         636                         53.00
# 5567                         553                         46.08
# 5568                          69                          5.75
# 5569                      324110                     27,009.17
#
#       valor_total_repassado_bpc  media_valor_repassado_bpc  \
# 0                  5,922,073.29                 493,506.11
# 1                 31,911,600.73               2,659,300.06
# 2                  1,073,335.21                  89,444.60
# 3                 22,925,459.55               1,910,454.96
# 4                  5,028,854.50                 419,071.21
# ...                         ...                        ...
# 5565               3,438,206.87                 286,517.24
# 5566               1,879,377.80                 156,614.82
# 5567               1,858,391.33                 154,865.94
# 5568                 353,934.00                  29,494.50
# 5569             633,832,483.31              52,819,373.61
#
#       valor_pcd_repassado_bpc  media_valor_pcd_repassado_bpc  \
# 0                4,692,484.70                     391,040.39
# 1               19,351,575.22                   1,612,631.27
# 2                  855,823.21                      71,318.60
# 3               14,753,222.96                   1,229,435.25
# 4                4,049,128.69                     337,427.39
# ...                       ...                            ...
# 5565             2,079,715.76                     173,309.65
# 5566             1,272,634.91                     106,052.91
# 5567             1,330,829.33                     110,902.44
# 5568               288,108.00                      24,009.00
# 5569           325,248,471.76                  27,104,039.31
#
#       valor_idoso_repassado_bpc  media_valor_idoso_repassado_pbc
# 0                  1,229,588.59                       102,465.72
# 1                 12,560,025.51                     1,046,668.79
# 2                    217,512.00                        18,126.00
# 3                  8,172,236.59                       681,019.72
# 4                    979,725.81                        81,643.82
# ...                         ...                              ...
# 5565               1,358,491.11                       113,207.59
# 5566                 606,742.89                        50,561.91
# 5567                 527,562.00                        43,963.50
# 5568                  65,826.00                         5,485.50
# 5569             308,584,011.55                    25,715,334.30
#
# [5570 rows x 13 columns]

# %% [markdown]
# # Integração

# %%
bd_2018 = cod_municipios[['Codigo_Municipio', 'Codigo_Municipio_2', 'Município', 'UF', 'Sigla_UF']]

# %%
bd_2018 = bd_2018.merge(pib_Munic[['Codigo_Municipio', 'PIB do Municipio']], how='right')

# %%
bd_2018 = bd_2018.merge(pib_Munic_BD_2018, how='right')

# %%
bd_2018 = bd_2018.merge(bolsa_familia, how='left', left_on='Codigo_Municipio_2', right_on='ibge')

# %%
bd_2018 = bd_2018.drop('ibge', axis=1)

# %%
bd_2018 = bd_2018.merge(bpc, how='left', left_on='Codigo_Municipio_2', right_on='ibge')

# %%
bd_2018 = bd_2018.drop('ibge', axis=1)

# %%
bd_2018 = bd_2018.merge(PAM_2018, how='right')

# %%
bd_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 95 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Codigo_Municipio                                               5570 non-null   int64
#  1   Codigo_Municipio_2                                             5570 non-null   int64
#  2   Município                                                      5570 non-null   object
#  3   UF                                                             5570 non-null   int64
#  4   Sigla_UF                                                       5570 non-null   object
#  5   PIB do Municipio                                               5570 non-null   int64
#  6   Produto Interno Bruto per capita, a preços correntes(R$ 1,00)  5570 non-null   float64
#  7   Atividade com maior valor adicionado bruto                     5570 non-null   object
#  8   qtd_familias_total_bolsa_familia                               5464 non-null   float64
#  9   media_qtd_familias_bolsa_familia                               5464 non-null   float64
#  10  valor_total_repassado_bolsa_familia                            5464 non-null   float64
#  11  media_valor_repassado_bolsa_familia                            5464 non-null   float64
#  12  num_beneficiados_bpc                                           5464 non-null   float64
#  13  media_beneficiados_bpc                                         5464 non-null   float64
#  14  num_pcd_beneficiados_bpc                                       5464 non-null   float64
#  15  media_pcd_beneficiados_bpc                                     5464 non-null   float64
#  16  num_idoso_beneficiados_bpc                                     5464 non-null   float64
#  17  media_idoso_beneficiados_bpc                                   5464 non-null   float64
#  18  valor_total_repassado_bpc                                      5464 non-null   float64
#  19  media_valor_repassado_bpc                                      5464 non-null   float64
#  20  valor_pcd_repassado_bpc                                        5464 non-null   float64
#  21  media_valor_pcd_repassado_bpc                                  5464 non-null   float64
#  22  valor_idoso_repassado_bpc                                      5464 non-null   float64
#  23  media_valor_idoso_repassado_pbc                                5464 non-null   float64
#  24  Produção de Abacate(toneladas)                                 5563 non-null   object
#  25  Produção de Abacaxi*(toneladas)                                5563 non-null   object
#  26  Produção de Açaí(toneladas)                                    5563 non-null   object
#  27  Produção de Alfafa fenada(toneladas)                           5563 non-null   object
#  28  Produção de Algodão arbóreo (em caroço)(toneladas)             5563 non-null   object
#  29  Produção de Algodão herbáceo (em caroço)(toneladas)            5563 non-null   object
#  30  Produção de Alho(toneladas)                                    5563 non-null   object
#  31  Produção de Amendoim (em casca)(toneladas)                     5563 non-null   object
#  32  Produção de Arroz (em casca)(toneladas)                        5563 non-null   object
#  33  Produção de Aveia (em grão)(toneladas)                         5563 non-null   object
#  34  Produção de Azeitona(toneladas)                                5563 non-null   object
#  35  Produção de Banana (cacho)(toneladas)                          5563 non-null   object
#  36  Produção de Batata-doce(toneladas)                             5563 non-null   object
#  37  Produção de Batata-inglesa(toneladas)                          5563 non-null   object
#  38  Produção de Borracha (látex coagulado)(toneladas)              5563 non-null   object
#  39  Produção de Borracha (látex líquido)(toneladas)                5563 non-null   object
#  40  Produção de Cacau (em amêndoa)(toneladas)                      5563 non-null   object
#  41  Produção de Café (em grão) Total(toneladas)                    5563 non-null   object
#  42  Produção de Café (em grão) Arábica(toneladas)                  5563 non-null   object
#  43  Produção de Café (em grão) Canephora(toneladas)                5563 non-null   object
#  44  Produção de Caju(toneladas)                                    5563 non-null   object
#  45  Produção de Cana-de-açúcar(toneladas)                          5563 non-null   object
#  46  Produção de Cana para forragem(toneladas)                      5563 non-null   object
#  47  Produção de Caqui(toneladas)                                   5563 non-null   object
#  48  Produção de Castanha de caju(toneladas)                        5563 non-null   object
#  49  Produção de Cebola(toneladas)                                  5563 non-null   object
#  50  Produção de Centeio (em grão)(toneladas)                       5563 non-null   object
#  51  Produção de Cevada (em grão)(toneladas)                        5563 non-null   object
#  52  Produção de Chá-da-índia (folha verde)(toneladas)              5563 non-null   object
#  53  Produção de Coco-da-baía*(toneladas)                           5563 non-null   object
#  54  Produção de Dendê (cacho de coco)(toneladas)                   5563 non-null   object
#  55  Produção de Erva-mate (folha verde)(toneladas)                 5563 non-null   object
#  56  Produção de Ervilha (em grão)(toneladas)                       5563 non-null   object
#  57  Produção de Fava (em grão)(toneladas)                          5563 non-null   object
#  58  Produção de Feijão (em grão)(toneladas)                        5563 non-null   object
#  59  Produção de Figo(toneladas)                                    5563 non-null   object
#  60  Produção de Fumo (em folha)(toneladas)                         5563 non-null   object
#  61  Produção de Girassol (em grão)(toneladas)                      5563 non-null   object
#  62  Produção de Goiaba(toneladas)                                  5563 non-null   object
#  63  Produção de Guaraná (semente)(toneladas)                       5563 non-null   object
#  64  Produção de Juta (fibra)(toneladas)                            5563 non-null   object
#  65  Produção de Laranja(toneladas)                                 5563 non-null   object
#  66  Produção de Limão(toneladas)                                   5563 non-null   object
#  67  Produção de Linho (semente)(toneladas)                         5563 non-null   object
#  68  Produção de Maçã(toneladas)                                    5563 non-null   object
#  69  Produção de Malva (fibra)(toneladas)                           5563 non-null   object
#  70  Produção de Mamão(toneladas)                                   5563 non-null   object
#  71  Produção de Mamona (baga)(toneladas)                           5563 non-null   object
#  72  Produção de Mandioca(toneladas)                                5563 non-null   object
#  73  Produção de Manga(toneladas)                                   5563 non-null   object
#  74  Produção de Maracujá(toneladas)                                5563 non-null   object
#  75  Produção de Marmelo(toneladas)                                 5563 non-null   object
#  76  Produção de Melancia(toneladas)                                5563 non-null   object
#  77  Produção de Melão(toneladas)                                   5563 non-null   object
#  78  Produção de Milho (em grão)(toneladas)                         5563 non-null   object
#  79  Produção de Noz (fruto seco)(toneladas)                        5563 non-null   object
#  80  Produção de Palmito(toneladas)                                 5563 non-null   object
#  81  Produção de Pera(toneladas)                                    5563 non-null   object
#  82  Produção de Pêssego(toneladas)                                 5563 non-null   object
#  83  Produção de Pimenta-do-reino(toneladas)                        5563 non-null   object
#  84  Produção de Rami (fibra)(toneladas)                            5563 non-null   object
#  85  Produção de Sisal ou agave (fibra)(toneladas)                  5563 non-null   object
#  86  Produção de Soja (em grão)(toneladas)                          5563 non-null   object
#  87  Produção de Sorgo (em grão)(toneladas)                         5563 non-null   object
#  88  Produção de Tangerina(toneladas)                               5563 non-null   object
#  89  Produção de Tomate(toneladas)                                  5563 non-null   object
#  90  Produção de Trigo (em grão)(toneladas)                         5563 non-null   object
#  91  Produção de Triticale (em grão)(toneladas)                     5563 non-null   object
#  92  Produção de Tungue (fruto seco)(toneladas)                     5563 non-null   object
#  93  Produção de Urucum (semente)(toneladas)                        5563 non-null   object
#  94  Produção de Uva(toneladas)                                     5563 non-null   object
# dtypes: float64(17), int64(4), object(74)
# memory usage: 4.0+ MB

# %%
bd_2018
# Out:
#       Codigo_Municipio  Codigo_Municipio_2                Município  UF  \
# 0              1100015              110001    Alta Floresta D'Oeste  11
# 1              1100379              110037  Alto Alegre dos Parecis  11
# 2              1100403              110040             Alto Paraíso  11
# 3              1100346              110034         Alvorada D'Oeste  11
# 4              1100023              110002                Ariquemes  11
# ...                ...                 ...                      ...  ..
# 5565           5222005              522200               Vianópolis  52
# 5566           5222054              522205           Vicentinópolis  52
# 5567           5222203              522220                 Vila Boa  52
# 5568           5222302              522230            Vila Propício  52
# 5569           5300108              530010                 Brasília  53
#
#      Sigla_UF  PIB do Municipio  \
# 0          RO            498980
# 1          RO            278342
# 2          RO            328757
# 3          RO            256200
# 4          RO           2464704
# ...       ...               ...
# 5565       GO            449973
# 5566       GO            339089
# 5567       GO            108469
# 5568       GO            179915
# 5569       DF         254817205
#
#       Produto Interno Bruto per capita, a preços correntes(R$ 1,00)  \
# 0                                             21,538.40
# 1                                             21,043.44
# 2                                             15,655.84
# 3                                             17,402.53
# 4                                             23,215.13
# ...                                                 ...
# 5565                                          32,734.86
# 5566                                          39,378.54
# 5567                                          18,000.23
# 5568                                          31,246.02
# 5569                                          85,661.39
#
#              Atividade com maior valor adicionado bruto  \
# 0     Administração, defesa, educação e saúde públic...
# 1     Administração, defesa, educação e saúde públic...
# 2     Administração, defesa, educação e saúde públic...
# 3     Administração, defesa, educação e saúde públic...
# 4                                       Demais serviços
# ...                                                 ...
# 5565                                    Demais serviços
# 5566  Agricultura, inclusive apoio à agricultura e a...
# 5567  Administração, defesa, educação e saúde públic...
# 5568  Agricultura, inclusive apoio à agricultura e a...
# 5569  Administração, defesa, educação e saúde públic...
#
#       qtd_familias_total_bolsa_familia  media_qtd_familias_bolsa_familia  ...  \
# 0                            18,402.00                          1,533.50  ...
# 1                             9,482.00                            790.17  ...
# 2                            13,559.00                          1,129.92  ...
# 3                            17,001.00                          1,416.75  ...
# 4                            48,424.00                          4,035.33  ...
# ...                                ...                               ...  ...
# 5565                          5,060.00                            421.67  ...
# 5566                         10,035.00                            836.25  ...
# 5567                          7,585.00                            632.08  ...
# 5568                          7,293.00                            607.75  ...
# 5569                        917,948.00                         76,495.67  ...
#
#       Produção de Sisal ou agave (fibra)(toneladas)  \
# 0                                                 -
# 1                                                 -
# 2                                                 -
# 3                                                 -
# 4                                                 -
# ...                                             ...
# 5565                                              -
# 5566                                              -
# 5567                                              -
# 5568                                              -
# 5569                                              -
#
#       Produção de Soja (em grão)(toneladas)  \
# 0                                      1350
# 1                                     10135
# 2                                     29966
# 3                                      1221
# 4                                     16800
# ...                                     ...
# 5565                                 136900
# 5566                                  69020
# 5567                                   7500
# 5568                                  45640
# 5569                                 253110
#
#       Produção de Sorgo (em grão)(toneladas)  \
# 0                                          -
# 1                                          -
# 2                                          -
# 3                                          -
# 4                                          -
# ...                                      ...
# 5565                                    1900
# 5566                                   14700
# 5567                                     900
# 5568                                       -
# 5569                                   30240
#
#       Produção de Tangerina(toneladas)  Produção de Tomate(toneladas)  \
# 0                                    -                            500
# 1                                    8                            400
# 2                                    -                             45
# 3                                    -                            175
# 4                                    -                             45
# ...                                ...                            ...
# 5565                                 -                          70000
# 5566                                 -                          27972
# 5567                                 -                              -
# 5568                                 -                           3255
# 5569                              2312                          28000
#
#       Produção de Trigo (em grão)(toneladas)  \
# 0                                          -
# 1                                          -
# 2                                          -
# 3                                          -
# 4                                          -
# ...                                      ...
# 5565                                     855
# 5566                                       -
# 5567                                       -
# 5568                                       -
# 5569                                    7620
#
#       Produção de Triticale (em grão)(toneladas)  \
# 0                                              -
# 1                                              -
# 2                                              -
# 3                                              -
# 4                                              -
# ...                                          ...
# 5565                                           -
# 5566                                           -
# 5567                                           -
# 5568                                           -
# 5569                                           -
#
#       Produção de Tungue (fruto seco)(toneladas)  \
# 0                                              -
# 1                                              -
# 2                                              -
# 3                                              -
# 4                                              -
# ...                                          ...
# 5565                                           -
# 5566                                           -
# 5567                                           -
# 5568                                           -
# 5569                                           -
#
#       Produção de Urucum (semente)(toneladas)  Produção de Uva(toneladas)
# 0                                           -                           -
# 1                                           5                           -
# 2                                           -                           -
# 3                                           5                           -
# 4                                          13                           -
# ...                                       ...                         ...
# 5565                                        -                           -
# 5566                                        -                           -
# 5567                                        -                           -
# 5568                                        -                           -
# 5569                                        -                        1425
#
# [5570 rows x 95 columns]
