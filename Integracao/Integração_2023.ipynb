# %%
import pandas as pd

# %%
# %run funcoes_gerais.ipynb

# %%
cod_municipios = pd.read_csv('../dataset/Código dos Municípios')

# %%
caged = pd.read_excel("../dataset/Economico/Renda e Desenvolvimento/PIB/caged_Atualizado.xlsx")

# %%
bolsa_familia = pd.read_csv("../dataset/Social/Projetos Sociais/Bolsa_Familia_2023.csv")
bpc = pd.read_csv("../dataset/Social/Projetos Sociais/bpc_2023.csv")

# %%
clin_Amb_BAS = pd.read_csv("../dataset/Condicao de Saude Tipico/Infraestrutura/Numero de clinicas Basicas/CNES_Ambulatorio_basico.csv", encoding='latin-1', skiprows=3, sep=';')
clin_Amb_ESP = pd.read_csv("../dataset/Condicao de Saude Tipico/Infraestrutura/Numero de clinicas especializadas/CNES_Ambulatorio_especializado.csv", encoding='latin-1', skiprows=3, sep=';')

# %%
leitos_internacao = pd.read_csv("../dataset/Condicao de Saude Tipico/Infraestrutura/numero de Leitos/CNES_Leitos_Internação_Hospitalar.csv",encoding='latin-1', skiprows=3, sep=';')

# %%
leitos_repouso_Ambulatorio_FEM = pd.read_csv("../dataset/Condicao de Saude Tipico/Infraestrutura/numero de Leitos/CNES_Leitos_repouso_Ambulatorio_FEM.csv",encoding='latin-1', skiprows=3, sep=';')
leitos_repouso_Ambulatorio_INDF = pd.read_csv("../dataset/Condicao de Saude Tipico/Infraestrutura/numero de Leitos/CNES_Leitos_repouso_Ambulatorio_INDF.csv",encoding='latin-1', skiprows=3, sep=';')
leitos_repouso_Ambulatorio_MASC = pd.read_csv("../dataset/Condicao de Saude Tipico/Infraestrutura/numero de Leitos/CNES_Leitos_repouso_Ambulatorio_MASC.csv",encoding='latin-1', skiprows=3, sep=';')
leitos_repouso_Ambulatorio_PED = pd.read_csv("../dataset/Condicao de Saude Tipico/Infraestrutura/numero de Leitos/CNES_Leitos_repouso_Ambulatorio_PED.csv",encoding='latin-1', skiprows=3, sep=';')

# %%
leitos_repouso_Urgencia_FEM = pd.read_csv("../dataset/Condicao de Saude Tipico/Infraestrutura/numero de Leitos/CNES_Leitos_repouso_Urgencia_FEM.csv",encoding='latin-1', skiprows=3, sep=';')
leitos_repouso_Urgencia_INDF = pd.read_csv("../dataset/Condicao de Saude Tipico/Infraestrutura/numero de Leitos/CNES_Leitos_repouso_Urgencia_INDF.csv",encoding='latin-1', skiprows=3, sep=';')
leitos_repouso_Urgencia_MASC = pd.read_csv("../dataset/Condicao de Saude Tipico/Infraestrutura/numero de Leitos/CNES_Leitos_repouso_Urgencia_MASC.csv",encoding='latin-1', skiprows=3, sep=';')
leitos_repouso_Urgencia_PED = pd.read_csv("../dataset/Condicao de Saude Tipico/Infraestrutura/numero de Leitos/CNES_Leitos_repouso_Urgencia_PED.csv",encoding='latin-1', skiprows=3, sep=';')

# %% [markdown]
# # Analise

# %% [markdown]
# ### CNES

# %% [markdown]
# ### Caged

# %%
caged
# Out:
#       Codigo_Municipio  Codigo_Municipio_2  UF                Municipio  \
# 0              1100015              110001  RO    Alta Floresta D Oeste
# 1              1100379              110037  RO  Alto Alegre dos Parecis
# 2              1100403              110040  RO             Alto Paraiso
# 3              1100346              110034  RO         Alvorada D Oeste
# 4              1100023              110002  RO                Ariquemes
# ...                ...                 ...  ..                      ...
# 5565           5222005              522200  GO               Vianopolis
# 5566           5222054              522205  GO           Vicentinopolis
# 5567           5222203              522220  GO                 Vila Boa
# 5568           5222302              522230  GO            Vila Propicio
# 5569           5300108              530010  DF                 Brasilia
#
#       2020_Estoque_media  2020_Estoque_MAX  2020_Estoque_MIN  \
# ...

# %%
caged = caged[['Codigo_Municipio', '2023_Estoque_media', '2023_Estoque_MAX', '2023_Estoque_MIN']]

# %%
caged
# Out:
#       Codigo_Municipio  2023_Estoque_media  2023_Estoque_MAX  2023_Estoque_MIN
# 0              1100015            2,272.17          2,334.00          2,208.00
# 1              1100379              675.42            697.00            653.00
# 2              1100403            1,277.00          1,310.00          1,216.00
# 3              1100346              872.42            899.00            861.00
# 4              1100023           19,121.75         19,513.00         18,246.00
# ...                ...                 ...               ...               ...
# 5565           5222005            2,833.58          2,981.00          2,674.00
# 5566           5222054            2,529.00          2,794.00          2,163.00
# 5567           5222203            1,785.00          2,169.00          1,312.00
# 5568           5222302            1,178.42          1,245.00          1,132.00
# 5569           5300108          954,068.33        973,513.00        929,370.00
#
# [5570 rows x 4 columns]

# %% [markdown]
# ### BPC

# %%
bpc
# Out:
#          ibge  anomes  bpc_ben  bpc_pcd_ben  bpc_idoso_ben   bpc_pcd_val  \
# 0      110001  202301      534          437             97    568,980.01
# 1      110002  202301     2990         1896           1094  2,471,252.69
# 2      110003  202301       79           60             19     78,121.92
# 3      110004  202301     2185         1484            701  1,934,806.12
# 4      110005  202301      454          353            101    459,609.92
# ...       ...     ...      ...          ...            ...           ...
# 66835  522200  202312      362          208            154    274,563.50
# 66836  522205  202312      145           98             47    129,364.82
# 66837  522220  202312      140          109             31    143,880.20
# 66838  522230  202312       38           32              6     42,240.00
# 66839  530010  202312    68260        35548          32712 46,946,189.43
#
#        bpc_idoso_val       bpc_val
# 0         127,596.00    696,576.01
# ...

# %%
bpc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66840 entries, 0 to 66839
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ibge           66840 non-null  int64
#  1   anomes         66840 non-null  int64
#  2   bpc_ben        66840 non-null  int64
#  3   bpc_pcd_ben    66840 non-null  int64
#  4   bpc_idoso_ben  66840 non-null  int64
#  5   bpc_pcd_val    66830 non-null  float64
#  6   bpc_idoso_val  66288 non-null  float64
#  7   bpc_val        66840 non-null  float64
# dtypes: float64(3), int64(5)
# memory usage: 4.1 MB

# %%
bpc['anomes'].value_counts()
# Out:
# anomes
# 202301    5570
# 202302    5570
# 202303    5570
# 202304    5570
# 202305    5570
# 202306    5570
# 202307    5570
# 202308    5570
# 202309    5570
# 202310    5570
# 202311    5570
# 202312    5570
# Name: count, dtype: int64

# %% [markdown]
# ### Bolsa Familia

# %%
bolsa_familia
# Out:
#        codigo_ibge  anomes_s  qtd_familias_beneficiarias_bolsa_familia_s  \
# 0           110001    202312                                        1724
# 1           110002    202312                                        6718
# 2           110003    202312                                         326
# 3           110004    202312                                        5921
# 4           110005    202312                                        1123
# ...            ...       ...                                         ...
# 55695       522200    202303                                         921
# 55696       522205    202303                                         717
# 55697       522220    202303                                         665
# 55698       522230    202303                                         749
# 55699       530010    202303                                      171957
#
#        valor_repassado_bolsa_familia_s  pbf_vlr_medio_benef_f
# ...

# %%
bolsa_familia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55700 entries, 0 to 55699
# Data columns (total 5 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   codigo_ibge                                 55700 non-null  int64
#  1   anomes_s                                    55700 non-null  int64
#  2   qtd_familias_beneficiarias_bolsa_familia_s  55700 non-null  int64
#  3   valor_repassado_bolsa_familia_s             55700 non-null  float64
#  4   pbf_vlr_medio_benef_f                       55700 non-null  float64
# dtypes: float64(2), int64(3)
# memory usage: 2.1 MB

# %%
bolsa_familia.rename(columns={'anomes_s': 'anomes', 'codigo_ibge':'ibge', 'qtd_familias_beneficiarias_bolsa_familia_s':'qtd_familias_beneficiarias_bolsa_familia', 'valor_repassado_bolsa_familia_s': 'valor_repassado_bolsa_familia'}, inplace=True)

# %%
bolsa_familia['anomes'].value_counts()
# Out:
# anomes
# 202312    5570
# 202311    5570
# 202310    5570
# 202309    5570
# 202308    5570
# 202307    5570
# 202306    5570
# 202305    5570
# 202304    5570
# 202303    5570
# Name: count, dtype: int64

# %% [markdown]
# # Transformação

# %% [markdown]
# ### CNES

# %% [markdown]
# #### Amb_BAS

# %%
clin_Amb_BAS = CNES(clin_Amb_BAS, '2023')
# Out:
# /tmp/ipykernel_8630/3025589086.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_8630/3025589086.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df.columns] =  df[df.columns].astype(float)

# %%
clin_Amb_BAS.rename(columns={'sum':'Numero Clinicas de Ambulatorio Basicas'}, inplace=True)

# %%
clin_Amb_BAS
# Out:
#       cod_municipio  Numero Clinicas de Ambulatorio Basicas
# 0        110,001.00                                  453.00
# 1        110,002.00                                1,024.00
# 2        110,003.00                                   96.00
# 3        110,004.00                                2,899.00
# 4        110,005.00                                  144.00
# ...             ...                                     ...
# 5436     522,200.00                                   36.00
# 5437     522,205.00                                  120.00
# 5438     522,220.00                                   72.00
# 5439     522,230.00                                   24.00
# 5440     530,010.00                               30,448.00
#
# [5441 rows x 2 columns]

# %% [markdown]
# ### AMB_ESP

# %%
clin_Amb_ESP = CNES(clin_Amb_ESP,'2023')
# Out:
# /tmp/ipykernel_8630/3025589086.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_8630/3025589086.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df.columns] =  df[df.columns].astype(float)

# %%
clin_Amb_ESP.rename(columns={'sum':'Numero Clinicas de Ambulatorio Especializadas'}, inplace=True)

# %%
clin_Amb_ESP
# Out:
#       cod_municipio  Numero Clinicas de Ambulatorio Especializadas
# 0        110,001.00                                         453.00
# 1        110,002.00                                       1,024.00
# 2        110,003.00                                          96.00
# 3        110,004.00                                       2,899.00
# 4        110,005.00                                         144.00
# ...             ...                                            ...
# 5436     522,200.00                                          36.00
# 5437     522,205.00                                         120.00
# 5438     522,220.00                                          72.00
# 5439     522,230.00                                          24.00
# 5440     530,010.00                                      30,448.00
#
# [5441 rows x 2 columns]

# %% [markdown]
# ### Internação

# %%
leitos_internacao = CNES(leitos_internacao,'2023')
# Out:
# /tmp/ipykernel_8630/3025589086.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_8630/3025589086.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df.columns] =  df[df.columns].astype(float)

# %%
leitos_internacao.rename(columns={'sum':'Numero Leitos de Internação'}, inplace=True)

# %%
leitos_internacao
# Out:
#       cod_municipio  Numero Leitos de Internação
# 0        110,001.00                       660.00
# 1        110,002.00                     3,117.00
# 2        110,003.00                        96.00
# 3        110,004.00                     4,958.00
# 4        110,005.00                       480.00
# ...             ...                          ...
# 3782     522,185.00                       882.00
# 3783     522,200.00                       480.00
# 3784     522,205.00                       192.00
# 3785     522,220.00                       156.00
# 3786     530,010.00                    96,106.00
#
# [3787 rows x 2 columns]

# %% [markdown]
# ### Leito Amb

# %%
leitos_repouso_Ambulatorio_FEM = CNES(leitos_repouso_Ambulatorio_FEM,'2023')
leitos_repouso_Ambulatorio_INDF = CNES(leitos_repouso_Ambulatorio_INDF,'2023')
leitos_repouso_Ambulatorio_MASC = CNES(leitos_repouso_Ambulatorio_MASC,'2023')
leitos_repouso_Ambulatorio_PED = CNES(leitos_repouso_Ambulatorio_PED,'2023')
# Out:
# /tmp/ipykernel_8630/3025589086.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_8630/3025589086.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df.columns] =  df[df.columns].astype(float)
# /tmp/ipykernel_8630/3025589086.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
leitos_repouso_Ambulatorio_FEM.rename(columns={'sum':'Numero Leitos de Ambulatorio Feminino'}, inplace=True)
leitos_repouso_Ambulatorio_INDF.rename(columns={'sum':'Numero Leitos de Ambulatorio Indiferente'}, inplace=True)
leitos_repouso_Ambulatorio_MASC.rename(columns={'sum':'Numero Leitos de Ambulatorio Masculino'}, inplace=True)
leitos_repouso_Ambulatorio_PED.rename(columns={'sum':'Numero Leitos de Ambulatorio Pediatro'}, inplace=True)

# %% [markdown]
# ### Leito Urg

# %%
leitos_repouso_Urgencia_FEM = CNES(leitos_repouso_Urgencia_FEM,'2023')
leitos_repouso_Urgencia_INDF = CNES(leitos_repouso_Urgencia_INDF,'2023')
leitos_repouso_Urgencia_MASC = CNES(leitos_repouso_Urgencia_MASC,'2023')
leitos_repouso_Urgencia_PED = CNES(leitos_repouso_Urgencia_PED,'2023')
# Out:
# /tmp/ipykernel_8630/3025589086.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace('-', np.nan, inplace=True)
# /tmp/ipykernel_8630/3025589086.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df.columns] =  df[df.columns].astype(float)
# /tmp/ipykernel_8630/3025589086.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
leitos_repouso_Urgencia_FEM.rename(columns={'sum':'Numero Leitos de Urgencia Feminino'}, inplace=True)
leitos_repouso_Urgencia_INDF.rename(columns={'sum':'Numero Leitos de Urgencia Indiferente'}, inplace=True)
leitos_repouso_Urgencia_MASC.rename(columns={'sum':'Numero Leitos de Urgencia Masculino'}, inplace=True)
leitos_repouso_Urgencia_PED.rename(columns={'sum':'Numero Leitos de Urgencia Pediatro'}, inplace=True)

# %% [markdown]
# ### Caged

# %%
caged = caged.round(2)

# %%
caged
# Out:
#       Codigo_Municipio  2023_Estoque_media  2023_Estoque_MAX  2023_Estoque_MIN
# 0              1100015            2,272.17          2,334.00          2,208.00
# 1              1100379              675.42            697.00            653.00
# 2              1100403            1,277.00          1,310.00          1,216.00
# 3              1100346              872.42            899.00            861.00
# 4              1100023           19,121.75         19,513.00         18,246.00
# ...                ...                 ...               ...               ...
# 5565           5222005            2,833.58          2,981.00          2,674.00
# 5566           5222054            2,529.00          2,794.00          2,163.00
# 5567           5222203            1,785.00          2,169.00          1,312.00
# 5568           5222302            1,178.42          1,245.00          1,132.00
# 5569           5300108          954,068.33        973,513.00        929,370.00
#
# [5570 rows x 4 columns]

# %% [markdown]
# ### BPC

# %%
bpc = BPC(bpc)

# %%
bpc
# Out:
#         ibge  num_beneficiados_bpc  media_beneficiados_bpc  \
# 0     110001                  6645                  553.75
# 1     110002                 38364                3,197.00
# 2     110003                   995                   82.92
# 3     110004                 27492                2,291.00
# 4     110005                  5596                  466.33
# ...      ...                   ...                     ...
# 5565  522200                  4179                  348.25
# 5566  522205                  1717                  143.08
# 5567  522220                  1695                  141.25
# 5568  522230                   407                   33.92
# 5569  530010                754638               62,886.50
#
#       num_pcd_beneficiados_bpc  media_pcd_beneficiados_bpc  \
# 0                         5410                      450.83
# 1                        24655                    2,054.58
# 2                          767                       63.92
# ...

# %% [markdown]
# ### Bolsa Familia

# %%
bolsa_familia = Bolsa_Familia(bolsa_familia)

# %%
bolsa_familia
# Out:
#         ibge  qtd_familias_total_bolsa_familia  \
# 0     110001                             17327
# 1     110002                             62368
# 2     110003                              3143
# 3     110004                             57651
# 4     110005                             10515
# ...      ...                               ...
# 5565  522200                             10123
# 5566  522205                              7433
# 5567  522220                              6667
# 5568  522230                              7514
# 5569  530010                           1796228
#
#       media_qtd_familias_bolsa_familia  valor_total_repassado_bolsa_familia  \
# 0                             1,732.70                        11,920,674.00
# 1                             6,236.80                        43,094,136.00
# 2                               314.30                         2,113,908.00
# 3                             5,765.10                        39,804,686.00
# ...

# %%
bolsa_familia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 5 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ibge                                 5570 non-null   int64
#  1   qtd_familias_total_bolsa_familia     5570 non-null   int64
#  2   media_qtd_familias_bolsa_familia     5570 non-null   float64
#  3   valor_total_repassado_bolsa_familia  5570 non-null   float64
#  4   media_valor_repassado_bolsa_familia  5570 non-null   float64
# dtypes: float64(3), int64(2)
# memory usage: 217.7 KB

# %% [markdown]
# # Integração

# %%
bd_2023 = cod_municipios[['Codigo_Municipio', 'Codigo_Municipio_2', 'Município', 'UF', 'Sigla_UF']]

# %%
bd_2023 = bd_2023.merge(caged, how='left')

# %%
bd_2023 = bd_2023.merge(bpc, how='left', left_on='Codigo_Municipio_2', right_on='ibge')

# %%
bd_2023 = bd_2023.drop('ibge', axis=1)

# %%
bd_2023 = bd_2023.merge(bolsa_familia, how='left', left_on='Codigo_Municipio_2', right_on='ibge')

# %%
bd_2023 = bd_2023.drop('ibge', axis=1)

# %%
bd_2023 = bd_2023.merge(clin_Amb_BAS, how='left',left_on='Codigo_Municipio_2', right_on='cod_municipio')
bd_2023 = bd_2023.merge(clin_Amb_ESP, how='left',left_on='Codigo_Municipio_2', right_on='cod_municipio')

# %%
bd_2023 = bd_2023.merge(leitos_internacao, how='left',left_on='Codigo_Municipio_2', right_on='cod_municipio')

# %%
bd_2023.drop(columns=['cod_municipio', 'cod_municipio_x', 'cod_municipio_y'], inplace=True)

# %%
bd_2023 = bd_2023.merge(leitos_repouso_Ambulatorio_FEM, how='left',left_on='Codigo_Municipio_2', right_on='cod_municipio')
bd_2023 = bd_2023.merge(leitos_repouso_Ambulatorio_MASC, how='left',left_on='Codigo_Municipio_2', right_on='cod_municipio')
bd_2023 = bd_2023.merge(leitos_repouso_Ambulatorio_INDF, how='left',left_on='Codigo_Municipio_2', right_on='cod_municipio')
bd_2023.drop(columns=['cod_municipio', 'cod_municipio_x', 'cod_municipio_y'], inplace=True)
bd_2023 = bd_2023.merge(leitos_repouso_Ambulatorio_PED, how='left',left_on='Codigo_Municipio_2', right_on='cod_municipio')

# %%
bd_2023 = bd_2023.merge(leitos_repouso_Urgencia_FEM, how='left',left_on='Codigo_Municipio_2', right_on='cod_municipio')
bd_2023 = bd_2023.merge(leitos_repouso_Urgencia_MASC, how='left',left_on='Codigo_Municipio_2', right_on='cod_municipio')
bd_2023.drop(columns=['cod_municipio', 'cod_municipio_x', 'cod_municipio_y'], inplace=True)
bd_2023 = bd_2023.merge(leitos_repouso_Urgencia_INDF, how='left',left_on='Codigo_Municipio_2', right_on='cod_municipio')
bd_2023 = bd_2023.merge(leitos_repouso_Urgencia_PED, how='left',left_on='Codigo_Municipio_2', right_on='cod_municipio')
bd_2023.drop(columns=['cod_municipio_x', 'cod_municipio_y'], inplace=True)

# %%
bd_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 35 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Codigo_Municipio                               5570 non-null   int64
#  1   Codigo_Municipio_2                             5570 non-null   int64
#  2   Município                                      5570 non-null   object
#  3   UF                                             5570 non-null   int64
#  4   Sigla_UF                                       5570 non-null   object
#  5   2023_Estoque_media                             5464 non-null   float64
#  6   2023_Estoque_MAX                               5464 non-null   float64
#  7   2023_Estoque_MIN                               5464 non-null   float64
#  8   num_beneficiados_bpc                           5464 non-null   float64
# ...

# %%
bd_2023.describe()
# Out:
#        Codigo_Municipio  Codigo_Municipio_2       UF  2023_Estoque_media  \
# count          5,570.00            5,570.00 5,570.00            5,464.00
# mean       3,253,590.77          319,572.75    32.38            8,172.48
# std          984,910.34          107,233.03     9.83           77,759.87
# min        1,100,015.00                0.00    11.00                2.80
# 25%        2,512,125.75          250,562.50    25.00              281.77
# 50%        3,146,280.00          314,255.00    31.00              873.79
# 75%        4,119,189.50          411,757.50    41.00            3,060.39
# max        5,300,108.00          530,010.00    53.00        4,734,667.92
#
#        2023_Estoque_MAX  2023_Estoque_MIN  num_beneficiados_bpc  \
# count          5,464.00          5,464.00              5,464.00
# mean           8,378.70          7,950.69             11,703.67
# std           79,302.67         76,347.13             63,059.48
# ...

# %%
bd_2023
# Out:
#       Codigo_Municipio  Codigo_Municipio_2                Município  UF  \
# 0              1100015              110001    Alta Floresta D'Oeste  11
# 1              1100379              110037  Alto Alegre dos Parecis  11
# 2              1100403              110040             Alto Paraíso  11
# 3              1100346              110034         Alvorada D'Oeste  11
# 4              1100023              110002                Ariquemes  11
# ...                ...                 ...                      ...  ..
# 5565           5222005              522200               Vianópolis  52
# 5566           5222054              522205           Vicentinópolis  52
# 5567           5222203              522220                 Vila Boa  52
# 5568           5222302              522230            Vila Propício  52
# 5569           5300108              530010                 Brasília  53
#
#      Sigla_UF  2023_Estoque_media  2023_Estoque_MAX  2023_Estoque_MIN  \
# ...
