# %%
import pandas as pd

# %%
# %run funcoes_gerais.ipynb

# %%
cod_municipios = pd.read_csv('../dataset/Código dos Municípios')

# %%
bolsa_familia = pd.read_csv("../dataset/Social/Projetos Sociais/Bolsa_Familia_2021.csv")
bpc = pd.read_csv("../dataset/Social/Projetos Sociais/bpc_2021.csv")

# %%
pib_Munic = pd.read_excel("../dataset/Economico/Renda e Desenvolvimento/PIB/PIB-Munic.xlsx")
pib_Munic_BD = pd.read_excel("../dataset/Economico/Renda e Desenvolvimento/PIB/PIB dos Municбpios - base de dados 2010-2021.xlsx")

# %%
PAM_2021 = pd.read_excel("../dataset/Producao Alimentar/Tipos de Alimento/PAM_2021.xlsx")

# %%
cempre_2021 = pd.read_excel("../dataset/Economico/Renda e Desenvolvimento/Renda Per Capta/Cempre_2021.xlsx")

# %% [markdown]
# # Analise

# %% [markdown]
# ### PIB Munic BD

# %%
pib_Munic_BD_2021 = pib_Munic_BD[pib_Munic_BD['Ano'] == 2021][['Código do Município', 'Produto Interno Bruto per capita, \na preços correntes\n(R$ 1,00)','Atividade com maior valor adicionado bruto']]

# %%
pib_Munic_BD_2021
# Out:
#        Código do Município  \
# 61255              1100015
# 61256              1100023
# 61257              1100031
# 61258              1100049
# 61259              1100056
# ...                    ...
# 66820              5222005
# 66821              5222054
# 66822              5222203
# 66823              5222302
# 66824              5300108
#
#        Produto Interno Bruto per capita, \na preços correntes\n(R$ 1,00)  \
# 61255                                          32,619.88
# 61256                                          28,878.27
# 61257                                          47,051.83
# 61258                                          32,313.26
# 61259                                          46,185.81
# ...                                                  ...
# 66820                                          60,900.61
# 66821                                          53,340.72
# 66822                                          27,886.97
# 66823                                          51,845.31
# 66824                                          92,732.27
#
#               Atividade com maior valor adicionado bruto
# 61255  Administração, defesa, educação e saúde públic...
# 61256                                    Demais serviços
# 61257  Agricultura, inclusive apoio à agricultura e a...
# 61258                                    Demais serviços
# 61259  Comércio e reparação de veículos automotores e...
# ...                                                  ...
# 66820  Agricultura, inclusive apoio à agricultura e a...
# 66821  Agricultura, inclusive apoio à agricultura e a...
# 66822  Agricultura, inclusive apoio à agricultura e a...
# 66823  Agricultura, inclusive apoio à agricultura e a...
# 66824  Administração, defesa, educação e saúde públic...
#
# [5570 rows x 3 columns]

# %% [markdown]
# ### Bolsa Familia

# %%
bolsa_familia
# Out:
#          ibge  anomes  qtd_familias_beneficiarias_bolsa_familia  \
# 0      110001  202101                                  1,515.00
# 1      110002  202101                                  3,928.00
# 2      110003  202101                                    190.00
# 3      110004  202101                                  3,115.00
# 4      110005  202101                                    710.00
# ...       ...     ...                                       ...
# 66835  522200  202112                                       NaN
# 66836  522205  202112                                       NaN
# 66837  522220  202112                                       NaN
# 66838  522230  202112                                       NaN
# 66839  530010  202112                                       NaN
#
#        valor_repassado_bolsa_familia
# 0                         243,899.00
# 1                         594,415.00
# 2                          31,455.00
# 3                         522,167.00
# 4                         106,890.00
# ...                              ...
# 66835                            NaN
# 66836                            NaN
# 66837                            NaN
# 66838                            NaN
# 66839                            NaN
#
# [66840 rows x 4 columns]

# %%
bolsa_familia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66840 entries, 0 to 66839
# Data columns (total 4 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   ibge                                      66840 non-null  int64
#  1   anomes                                    66840 non-null  int64
#  2   qtd_familias_beneficiarias_bolsa_familia  55700 non-null  float64
#  3   valor_repassado_bolsa_familia             55700 non-null  float64
# dtypes: float64(2), int64(2)
# memory usage: 2.0 MB

# %%
bolsa_familia['anomes'].value_counts()
# Out:
# anomes
# 202101    5570
# 202102    5570
# 202103    5570
# 202104    5570
# 202105    5570
# 202106    5570
# 202107    5570
# 202108    5570
# 202109    5570
# 202110    5570
# 202111    5570
# 202112    5570
# Name: count, dtype: int64

# %% [markdown]
# ### BPC

# %%
bpc
# Out:
#          ibge  anomes  bpc_ben  bpc_pcd_ben  bpc_idoso_ben   bpc_pcd_val  \
# 0      110001  202101      504       402.00         102.00    442,200.00
# 1      110002  202101     2828     1,762.00       1,066.00  1,941,756.66
# 2      110003  202101       81        68.00          13.00     74,800.00
# 3      110004  202101     2026     1,332.00         694.00  1,466,300.00
# 4      110005  202101      437       349.00          88.00    383,900.00
# ...       ...     ...      ...          ...            ...           ...
# 66835  522200  202112      298       175.00         123.00    192,500.00
# 66836  522205  202112      145       100.00          45.00    110,000.00
# 66837  522220  202112      136       100.00          36.00    110,000.00
# 66838  522230  202112       31        27.00           4.00     29,700.00
# 66839  530010  202112    54460    27,503.00      26,957.00 30,289,883.28
#
#        bpc_idoso_val       bpc_val
# 0         112,200.00    554,400.00
# 1       1,173,700.00  3,115,456.66
# 2          14,300.00     89,100.00
# 3         765,600.00  2,231,900.00
# 4          96,800.00    480,700.00
# ...              ...           ...
# 66835     135,300.00    327,800.00
# 66836      49,500.00    159,500.00
# 66837      39,600.00    149,600.00
# 66838       4,400.00     34,100.00
# 66839  29,671,577.49 59,961,460.77
#
# [66840 rows x 8 columns]

# %%
bpc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66840 entries, 0 to 66839
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ibge           66840 non-null  int64
#  1   anomes         66840 non-null  int64
#  2   bpc_ben        66840 non-null  int64
#  3   bpc_pcd_ben    66822 non-null  float64
#  4   bpc_idoso_ben  66822 non-null  float64
#  5   bpc_pcd_val    66813 non-null  float64
#  6   bpc_idoso_val  66618 non-null  float64
#  7   bpc_val        66840 non-null  float64
# dtypes: float64(5), int64(3)
# memory usage: 4.1 MB

# %%
bpc['anomes'].value_counts()
# Out:
# anomes
# 202101    5570
# 202102    5570
# 202103    5570
# 202104    5570
# 202105    5570
# 202106    5570
# 202107    5570
# 202108    5570
# 202109    5570
# 202110    5570
# 202111    5570
# 202112    5570
# Name: count, dtype: int64

# %% [markdown]
# # Transformação

# %% [markdown]
# ### PAM

# %%
PAM_2021 = PAM(PAM_2021)

# %% [markdown]
# ### PIB Munic

# %%
# for col in pib_Munic.columns[2:]:
#     pib_Munic[col] = pib_Munic[col].apply(lambda x: f"{x:,.1f}".replace(",", "X").replace(".", ",").replace("X", "."))
pib_Munic = pib_Munic.round(2)

# %%
pib_Munic = pib_Munic.rename(columns={'Cód.':'Codigo_Municipio','2021':'PIB do Municipio'})

# %%
pib_Munic.head()
# Out:
#    Codigo_Municipio                   Município     2017     2018     2019  \
# 0           1100015  Alta Floresta D'Oeste (RO)   485374   498980   495775
# 1           1100023              Ariquemes (RO)  2287910  2464704  2579278
# 2           1100031                 Cabixi (RO)   138110   140503   139976
# 3           1100049                 Cacoal (RO)  2082761  2175840  2261930
# 4           1100056             Cerejeiras (RO)   439245   470647   506494
#
#       2020  PIB do Municipio
# 0   570242            734469
# 1  2817331           3209761
# 2   167153            238412
# 3  2518845           2792383
# 4   600630            743037

# %% [markdown]
# ### PIB MUnic BD

# %%
pib_Munic_BD_2021 = pib_Munic_BD_2021.rename(columns={'Código do Município': 'Codigo_Municipio', 
                        'Produto Interno Bruto per capita, \na preços correntes\n(R$ 1,00)': 'Produto Interno Bruto per capita, a preços correntes(R$ 1,00)'})
pib_Munic_BD_2021 = pib_Munic_BD_2021.round(2)
# pib_Munic_BD_2021['Produto Interno Bruto per capita, a preços correntes(R$ 1,00)'] = pib_Munic_BD_2021['Produto Interno Bruto per capita, a preços correntes(R$ 1,00)'].apply(lambda x: f"{x:,.1f}".replace(",", "X").replace(".", ",").replace("X", "."))

# %%
pib_Munic_BD_2021
# Out:
#        Codigo_Municipio  \
# 61255           1100015
# 61256           1100023
# 61257           1100031
# 61258           1100049
# 61259           1100056
# ...                 ...
# 66820           5222005
# 66821           5222054
# 66822           5222203
# 66823           5222302
# 66824           5300108
#
#        Produto Interno Bruto per capita, a preços correntes(R$ 1,00)  \
# 61255                                          32,619.88
# 61256                                          28,878.27
# 61257                                          47,051.83
# 61258                                          32,313.26
# 61259                                          46,185.81
# ...                                                  ...
# 66820                                          60,900.61
# 66821                                          53,340.72
# 66822                                          27,886.97
# 66823                                          51,845.31
# 66824                                          92,732.27
#
#               Atividade com maior valor adicionado bruto
# 61255  Administração, defesa, educação e saúde públic...
# 61256                                    Demais serviços
# 61257  Agricultura, inclusive apoio à agricultura e a...
# 61258                                    Demais serviços
# 61259  Comércio e reparação de veículos automotores e...
# ...                                                  ...
# 66820  Agricultura, inclusive apoio à agricultura e a...
# 66821  Agricultura, inclusive apoio à agricultura e a...
# 66822  Agricultura, inclusive apoio à agricultura e a...
# 66823  Agricultura, inclusive apoio à agricultura e a...
# 66824  Administração, defesa, educação e saúde públic...
#
# [5570 rows x 3 columns]

# %% [markdown]
# ### CEMPRE

# %%
cempre_2021 = CEMPRE(cempre_2021)

# %%
cempre_2021
# Out:
#       Codigo_Municipio  Número de unidades\nlocais  Pessoal ocupado Total  \
# 0              1100015                      521.00               2,913.00
# 1              1100379                      170.00               1,158.00
# 2              1100403                      266.00               1,601.00
# 3              1100346                      268.00               1,620.00
# 4              1100023                    2,879.00              20,851.00
# ...                ...                         ...                    ...
# 5565           5222005                      466.00               2,846.00
# 5566           5222054                      208.00               1,989.00
# 5567           5222203                       60.00                 848.00
# 5568           5222302                      107.00               1,256.00
# 5569           5300108                  111,980.00           1,399,758.00
#
#       Pessoal ocupado Assalariado  Pessoal assalariado médio  \
# 0                        2,356.00                   2,603.01
# 1                          955.00                     940.96
# 2                        1,302.00                   1,265.78
# 3                        1,308.00                   1,279.66
# 4                       17,176.00                  16,650.72
# ...                           ...                        ...
# 5565                     2,333.00                   2,156.03
# 5566                     1,748.00                   2,173.06
# 5567                       800.00                   1,127.87
# 5568                     1,132.00                   1,024.62
# 5569                 1,268,259.00               1,266,004.23
#
#       Salários\ne outras\nremunerações\n(1 000 R$)  \
# 0                                        68,628.62
# 1                                        27,837.93
# 2                                        37,091.55
# 3                                        30,186.24
# 4                                       488,764.26
# ...                                            ...
# 5565                                     66,581.55
# 5566                                     64,097.41
# 5567                                     34,213.96
# 5568                                     27,187.85
# 5569                                 92,894,836.20
#
#       Salário médio\n mensal \n(salários mínimos)  (1) (2)   \
# 0                                                  1.84
# 1                                                  2.07
# 2                                                  2.05
# 3                                                  1.65
# 4                                                  2.05
# ...                                                 ...
# 5565                                               2.16
# 5566                                               2.06
# 5567                                               2.12
# 5568                                               1.86
# 5569                                               5.13
#
#       Salário médio mensal(R$)  Número de empresas atuantes
# 0                     2,028.08                       514.00
# 1                     2,275.74                       170.00
# 2                     2,254.10                       265.00
# 3                     1,814.56                       262.00
# 4                     2,258.00                     2,778.00
# ...                        ...                          ...
# 5565                  2,375.50                       462.00
# 5566                  2,268.95                       208.00
# 5567                  2,333.46                        60.00
# 5568                  2,041.12                       101.00
# 5569                  5,644.34                   105,511.00
#
# [5570 rows x 9 columns]

# %% [markdown]
# ### Bolsa Familia

# %%
bolsa_familia = Bolsa_Familia(bolsa_familia)

# %%
bolsa_familia
# Out:
#         ibge  qtd_familias_total_bolsa_familia  \
# 0     110001                         15,375.00
# 1     110002                         45,176.00
# 2     110003                          2,164.00
# 3     110004                         35,790.00
# 4     110005                          7,428.00
# ...      ...                               ...
# 5565  522200                          3,639.00
# 5566  522205                          7,501.00
# 5567  522220                          5,418.00
# 5568  522230                          5,276.00
# 5569  530010                        894,073.00
#
#       media_qtd_familias_bolsa_familia  valor_total_repassado_bolsa_familia  \
# 0                             1,537.50                         1,152,208.00
# 1                             4,517.60                         3,553,759.00
# 2                               216.40                           171,043.00
# 3                             3,579.00                         3,645,274.00
# 4                               742.80                           491,264.00
# ...                                ...                                  ...
# 5565                            363.90                           319,806.00
# 5566                            750.10                           628,487.00
# 5567                            541.80                           448,975.00
# 5568                            527.60                           390,500.00
# 5569                         89,407.30                        95,708,645.00
#
#       media_valor_repassado_bolsa_familia
# 0                              115,220.80
# 1                              355,375.90
# 2                               17,104.30
# 3                              364,527.40
# 4                               49,126.40
# ...                                   ...
# 5565                            31,980.60
# 5566                            62,848.70
# 5567                            44,897.50
# 5568                            39,050.00
# 5569                         9,570,864.50
#
# [5570 rows x 5 columns]

# %%
bolsa_familia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 5 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ibge                                 5570 non-null   int64
#  1   qtd_familias_total_bolsa_familia     5570 non-null   float64
#  2   media_qtd_familias_bolsa_familia     5570 non-null   float64
#  3   valor_total_repassado_bolsa_familia  5570 non-null   float64
#  4   media_valor_repassado_bolsa_familia  5570 non-null   float64
# dtypes: float64(4), int64(1)
# memory usage: 217.7 KB

# %% [markdown]
# ### BPC

# %%
bpc = BPC(bpc)

# %%
bpc
# Out:
#         ibge  num_beneficiados_bpc  media_beneficiados_bpc  \
# 0     110001                  6046                  503.83
# 1     110002                 33961                2,830.08
# 2     110003                   962                   80.17
# 3     110004                 24194                2,016.17
# 4     110005                  5146                  428.83
# ...      ...                   ...                     ...
# 5565  522200                  3618                  301.50
# 5566  522205                  1733                  144.42
# 5567  522220                  1693                  141.08
# 5568  522230                   353                   29.42
# 5569  530010                650684               54,223.67
#
#       num_pcd_beneficiados_bpc  media_pcd_beneficiados_bpc  \
# 0                     4,888.00                      407.33
# 1                    21,427.00                    1,785.58
# 2                       794.00                       66.17
# 3                    16,078.00                    1,339.83
# 4                     4,104.00                      342.00
# ...                        ...                         ...
# 5565                  2,159.00                      179.92
# 5566                  1,165.00                       97.08
# 5567                  1,250.00                      104.17
# 5568                    285.00                       23.75
# 5569                328,790.00                   27,399.17
#
#       num_idoso_beneficiados_bpc  media_idoso_beneficiados_bpc  \
# 0                       1,158.00                         96.50
# 1                      12,534.00                      1,044.50
# 2                         168.00                         14.00
# 3                       8,116.00                        676.33
# 4                       1,042.00                         86.83
# ...                          ...                           ...
# 5565                    1,459.00                        121.58
# 5566                      568.00                         47.33
# 5567                      443.00                         36.92
# 5568                       68.00                          5.67
# 5569                  321,894.00                     26,824.50
#
#       valor_total_repassado_bpc  media_valor_repassado_bpc  \
# 0                  6,660,595.29                 555,049.61
# 1                 37,397,455.14               3,116,454.60
# 2                  1,058,222.16                  88,185.18
# 3                 26,644,589.75               2,220,382.48
# 4                  5,663,961.60                 471,996.80
# ...                         ...                        ...
# 5565               3,982,034.56                 331,836.21
# 5566               1,908,531.77                 159,044.31
# 5567               1,863,408.40                 155,284.03
# 5568                 389,404.70                  32,450.39
# 5569             716,494,211.94              59,707,851.00
#
#       valor_pcd_repassado_bpc  media_valor_pcd_repassado_bpc  \
# 0                5,381,278.60                     448,439.88
# 1               23,592,243.59                   1,966,020.30
# 2                  873,418.25                      72,784.85
# 3               17,701,442.00                   1,475,120.17
# 4                4,516,653.22                     376,387.77
# ...                       ...                            ...
# 5565             2,376,021.17                     198,001.76
# 5566             1,281,520.72                     106,793.39
# 5567             1,376,107.10                     114,675.59
# 5568               313,503.57                      26,125.30
# 5569           362,046,651.08                  30,170,554.26
#
#       valor_idoso_repassado_bpc  media_valor_idoso_repassado_pbc
# 0                  1,279,316.69                       106,609.72
# 1                 13,805,211.55                     1,150,434.30
# 2                    184,803.91                        15,400.33
# 3                  8,943,147.75                       745,262.31
# 4                  1,147,308.38                        95,609.03
# ...                         ...                              ...
# 5565               1,606,013.39                       133,834.45
# 5566                 627,011.05                        52,250.92
# 5567                 487,301.30                        40,608.44
# 5568                  75,901.13                         6,325.09
# 5569             354,447,560.86                    29,537,296.74
#
# [5570 rows x 13 columns]

# %% [markdown]
# # Integração

# %%
bd_2021 = cod_municipios[['Codigo_Municipio', 'Codigo_Municipio_2', 'Município', 'UF', 'Sigla_UF']]

# %%
bd_2021 = bd_2021.merge(pib_Munic[['Codigo_Municipio', 'PIB do Municipio']], how='left')

# %%
bd_2021 = bd_2021.merge(pib_Munic_BD_2021, how='left')

# %%
bd_2021 = bd_2021.merge(cempre_2021[['Codigo_Municipio', 'Salário médio mensal(R$)']], how='left')

# %%
bd_2021 = bd_2021.merge(bolsa_familia, how='left', left_on='Codigo_Municipio_2', right_on='ibge')

# %%
bd_2021 = bd_2021.drop('ibge', axis=1)

# %%
bd_2021 = bd_2021.merge(bpc, how='left', left_on='Codigo_Municipio_2', right_on='ibge')

# %%
bd_2021 = bd_2021.drop('ibge', axis=1)

# %%
bd_2021 = bd_2021.merge(PAM_2021, how='left')

# %%
bd_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5570 entries, 0 to 5569
# Data columns (total 96 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Codigo_Municipio                                               5570 non-null   int64
#  1   Codigo_Municipio_2                                             5570 non-null   int64
#  2   Município                                                      5570 non-null   object
#  3   UF                                                             5570 non-null   int64
#  4   Sigla_UF                                                       5570 non-null   object
#  5   PIB do Municipio                                               5570 non-null   int64
#  6   Produto Interno Bruto per capita, a preços correntes(R$ 1,00)  5570 non-null   float64
#  7   Atividade com maior valor adicionado bruto                     5570 non-null   object
#  8   Salário médio mensal(R$)                                       5536 non-null   float64
#  9   qtd_familias_total_bolsa_familia                               5464 non-null   float64
#  10  media_qtd_familias_bolsa_familia                               5464 non-null   float64
#  11  valor_total_repassado_bolsa_familia                            5464 non-null   float64
#  12  media_valor_repassado_bolsa_familia                            5464 non-null   float64
#  13  num_beneficiados_bpc                                           5464 non-null   float64
#  14  media_beneficiados_bpc                                         5464 non-null   float64
#  15  num_pcd_beneficiados_bpc                                       5464 non-null   float64
#  16  media_pcd_beneficiados_bpc                                     5463 non-null   float64
#  17  num_idoso_beneficiados_bpc                                     5464 non-null   float64
#  18  media_idoso_beneficiados_bpc                                   5463 non-null   float64
#  19  valor_total_repassado_bpc                                      5464 non-null   float64
#  20  media_valor_repassado_bpc                                      5464 non-null   float64
#  21  valor_pcd_repassado_bpc                                        5464 non-null   float64
#  22  media_valor_pcd_repassado_bpc                                  5463 non-null   float64
#  23  valor_idoso_repassado_bpc                                      5464 non-null   float64
#  24  media_valor_idoso_repassado_pbc                                5463 non-null   float64
#  25  Produção de Abacate(toneladas)                                 5563 non-null   object
#  26  Produção de Abacaxi*(toneladas)                                5563 non-null   object
#  27  Produção de Açaí(toneladas)                                    5563 non-null   object
#  28  Produção de Alfafa fenada(toneladas)                           5563 non-null   object
#  29  Produção de Algodão arbóreo (em caroço)(toneladas)             5563 non-null   object
#  30  Produção de Algodão herbáceo (em caroço)(toneladas)            5563 non-null   object
#  31  Produção de Alho(toneladas)                                    5563 non-null   object
#  32  Produção de Amendoim (em casca)(toneladas)                     5563 non-null   object
#  33  Produção de Arroz (em casca)(toneladas)                        5563 non-null   object
#  34  Produção de Aveia (em grão)(toneladas)                         5563 non-null   object
#  35  Produção de Azeitona(toneladas)                                5563 non-null   object
#  36  Produção de Banana (cacho)(toneladas)                          5563 non-null   object
#  37  Produção de Batata-doce(toneladas)                             5563 non-null   object
#  38  Produção de Batata-inglesa(toneladas)                          5563 non-null   object
#  39  Produção de Borracha (látex coagulado)(toneladas)              5563 non-null   object
#  40  Produção de Borracha (látex líquido)(toneladas)                5563 non-null   object
#  41  Produção de Cacau (em amêndoa)(toneladas)                      5563 non-null   object
#  42  Produção de Café (em grão) Total(toneladas)                    5563 non-null   object
#  43  Produção de Café (em grão) Arábica(toneladas)                  5563 non-null   object
#  44  Produção de Café (em grão) Canephora(toneladas)                5563 non-null   object
#  45  Produção de Caju(toneladas)                                    5563 non-null   object
#  46  Produção de Cana-de-açúcar(toneladas)                          5563 non-null   object
#  47  Produção de Cana para forragem(toneladas)                      5563 non-null   object
#  48  Produção de Caqui(toneladas)                                   5563 non-null   object
#  49  Produção de Castanha de caju(toneladas)                        5563 non-null   object
#  50  Produção de Cebola(toneladas)                                  5563 non-null   object
#  51  Produção de Centeio (em grão)(toneladas)                       5563 non-null   object
#  52  Produção de Cevada (em grão)(toneladas)                        5563 non-null   object
#  53  Produção de Chá-da-índia (folha verde)(toneladas)              5563 non-null   object
#  54  Produção de Coco-da-baía*(toneladas)                           5563 non-null   object
#  55  Produção de Dendê (cacho de coco)(toneladas)                   5563 non-null   object
#  56  Produção de Erva-mate (folha verde)(toneladas)                 5563 non-null   object
#  57  Produção de Ervilha (em grão)(toneladas)                       5563 non-null   object
#  58  Produção de Fava (em grão)(toneladas)                          5563 non-null   object
#  59  Produção de Feijão (em grão)(toneladas)                        5563 non-null   object
#  60  Produção de Figo(toneladas)                                    5563 non-null   object
#  61  Produção de Fumo (em folha)(toneladas)                         5563 non-null   object
#  62  Produção de Girassol (em grão)(toneladas)                      5563 non-null   object
#  63  Produção de Goiaba(toneladas)                                  5563 non-null   object
#  64  Produção de Guaraná (semente)(toneladas)                       5563 non-null   object
#  65  Produção de Juta (fibra)(toneladas)                            5563 non-null   object
#  66  Produção de Laranja(toneladas)                                 5563 non-null   object
#  67  Produção de Limão(toneladas)                                   5563 non-null   object
#  68  Produção de Linho (semente)(toneladas)                         5563 non-null   object
#  69  Produção de Maçã(toneladas)                                    5563 non-null   object
#  70  Produção de Malva (fibra)(toneladas)                           5563 non-null   object
#  71  Produção de Mamão(toneladas)                                   5563 non-null   object
#  72  Produção de Mamona (baga)(toneladas)                           5563 non-null   object
#  73  Produção de Mandioca(toneladas)                                5563 non-null   object
#  74  Produção de Manga(toneladas)                                   5563 non-null   object
#  75  Produção de Maracujá(toneladas)                                5563 non-null   object
#  76  Produção de Marmelo(toneladas)                                 5563 non-null   object
#  77  Produção de Melancia(toneladas)                                5563 non-null   object
#  78  Produção de Melão(toneladas)                                   5563 non-null   object
#  79  Produção de Milho (em grão)(toneladas)                         5563 non-null   object
#  80  Produção de Noz (fruto seco)(toneladas)                        5563 non-null   object
#  81  Produção de Palmito(toneladas)                                 5563 non-null   object
#  82  Produção de Pera(toneladas)                                    5563 non-null   object
#  83  Produção de Pêssego(toneladas)                                 5563 non-null   object
#  84  Produção de Pimenta-do-reino(toneladas)                        5563 non-null   object
#  85  Produção de Rami (fibra)(toneladas)                            5563 non-null   object
#  86  Produção de Sisal ou agave (fibra)(toneladas)                  5563 non-null   object
#  87  Produção de Soja (em grão)(toneladas)                          5563 non-null   object
#  88  Produção de Sorgo (em grão)(toneladas)                         5563 non-null   object
#  89  Produção de Tangerina(toneladas)                               5563 non-null   object
#  90  Produção de Tomate(toneladas)                                  5563 non-null   object
#  91  Produção de Trigo (em grão)(toneladas)                         5563 non-null   object
#  92  Produção de Triticale (em grão)(toneladas)                     5563 non-null   object
#  93  Produção de Tungue (fruto seco)(toneladas)                     5563 non-null   object
#  94  Produção de Urucum (semente)(toneladas)                        5563 non-null   object
#  95  Produção de Uva(toneladas)                                     5563 non-null   object
# dtypes: float64(18), int64(4), object(74)
# memory usage: 4.1+ MB

# %%
bd_2021
# Out:
#       Codigo_Municipio  Codigo_Municipio_2                Município  UF  \
# 0              1100015              110001    Alta Floresta D'Oeste  11
# 1              1100379              110037  Alto Alegre dos Parecis  11
# 2              1100403              110040             Alto Paraíso  11
# 3              1100346              110034         Alvorada D'Oeste  11
# 4              1100023              110002                Ariquemes  11
# ...                ...                 ...                      ...  ..
# 5565           5222005              522200               Vianópolis  52
# 5566           5222054              522205           Vicentinópolis  52
# 5567           5222203              522220                 Vila Boa  52
# 5568           5222302              522230            Vila Propício  52
# 5569           5300108              530010                 Brasília  53
#
#      Sigla_UF  PIB do Municipio  \
# 0          RO            734469
# 1          RO            483672
# 2          RO            510361
# 3          RO            352628
# 4          RO           3209761
# ...       ...               ...
# 5565       GO            857968
# 5566       GO            480173
# 5567       GO            179899
# 5568       GO            308013
# 5569       DF         286943782
#
#       Produto Interno Bruto per capita, a preços correntes(R$ 1,00)  \
# 0                                             32,619.88
# 1                                             36,454.01
# 2                                             22,929.34
# 3                                             25,539.82
# 4                                             28,878.27
# ...                                                 ...
# 5565                                          60,900.61
# 5566                                          53,340.72
# 5567                                          27,886.97
# 5568                                          51,845.31
# 5569                                          92,732.27
#
#              Atividade com maior valor adicionado bruto  \
# 0     Administração, defesa, educação e saúde públic...
# 1     Agricultura, inclusive apoio à agricultura e a...
# 2     Administração, defesa, educação e saúde públic...
# 3                  Pecuária, inclusive apoio à pecuária
# 4                                       Demais serviços
# ...                                                 ...
# 5565  Agricultura, inclusive apoio à agricultura e a...
# 5566  Agricultura, inclusive apoio à agricultura e a...
# 5567  Agricultura, inclusive apoio à agricultura e a...
# 5568  Agricultura, inclusive apoio à agricultura e a...
# 5569  Administração, defesa, educação e saúde públic...
#
#       Salário médio mensal(R$)  qtd_familias_total_bolsa_familia  ...  \
# 0                     2,028.08                         15,375.00  ...
# 1                     2,275.74                          8,128.00  ...
# 2                     2,254.10                         11,708.00  ...
# 3                     1,814.56                         12,452.00  ...
# 4                     2,258.00                         45,176.00  ...
# ...                        ...                               ...  ...
# 5565                  2,375.50                          3,639.00  ...
# 5566                  2,268.95                          7,501.00  ...
# 5567                  2,333.46                          5,418.00  ...
# 5568                  2,041.12                          5,276.00  ...
# 5569                  5,644.34                        894,073.00  ...
#
#       Produção de Sisal ou agave (fibra)(toneladas)  \
# 0                                                 -
# 1                                                 -
# 2                                                 -
# 3                                                 -
# 4                                                 -
# ...                                             ...
# 5565                                              -
# 5566                                              -
# 5567                                              -
# 5568                                              -
# 5569                                              -
#
#       Produção de Soja (em grão)(toneladas)  \
# 0                                      2500
# 1                                      1800
# 2                                     71940
# 3                                      1980
# 4                                     22731
# ...                                     ...
# 5565                                 160000
# 5566                                  88200
# 5567                                   5300
# 5568                                  66555
# 5569                                 312000
#
#       Produção de Sorgo (em grão)(toneladas)  \
# 0                                          -
# 1                                          -
# 2                                          -
# 3                                          -
# 4                                          -
# ...                                      ...
# 5565                                   15000
# 5566                                   16240
# 5567                                     710
# 5568                                       -
# 5569                                   35100
#
#       Produção de Tangerina(toneladas)  Produção de Tomate(toneladas)  \
# 0                                    4                            412
# 1                                    2                             62
# 2                                    -                             60
# 3                                    -                            210
# 4                                    -                             31
# ...                                ...                            ...
# 5565                                 -                          70000
# 5566                                 -                          16100
# 5567                                 -                              -
# 5568                                 -                           1900
# 5569                              2312                          28000
#
#       Produção de Trigo (em grão)(toneladas)  \
# 0                                          -
# 1                                          -
# 2                                          -
# 3                                          -
# 4                                          -
# ...                                      ...
# 5565                                     550
# 5566                                       -
# 5567                                       -
# 5568                                       -
# 5569                                   10500
#
#       Produção de Triticale (em grão)(toneladas)  \
# 0                                              -
# 1                                              -
# 2                                              -
# 3                                              -
# 4                                              -
# ...                                          ...
# 5565                                           -
# 5566                                           -
# 5567                                           -
# 5568                                           -
# 5569                                           -
#
#       Produção de Tungue (fruto seco)(toneladas)  \
# 0                                              -
# 1                                              -
# 2                                              -
# 3                                              -
# 4                                              -
# ...                                          ...
# 5565                                           -
# 5566                                           -
# 5567                                           -
# 5568                                           -
# 5569                                           -
#
#       Produção de Urucum (semente)(toneladas)  Produção de Uva(toneladas)
# 0                                          36                           -
# 1                                           2                           -
# 2                                           5                           -
# 3                                           5                           -
# 4                                          10                           -
# ...                                       ...                         ...
# 5565                                        -                           -
# 5566                                        -                           -
# 5567                                        -                           -
# 5568                                        -                           -
# 5569                                        -                        1425
#
# [5570 rows x 96 columns]

# %%
bd_2021.describe()
# Out:
#        Codigo_Municipio  Codigo_Municipio_2       UF  PIB do Municipio  \
# count          5,570.00            5,570.00 5,570.00          5,570.00
# mean       3,253,590.77          319,572.75    32.38      1,617,978.82
# std          984,910.34          107,233.03     9.83     13,774,623.68
# min        1,100,015.00                0.00    11.00         18,051.00
# 25%        2,512,125.75          250,562.50    25.00        112,490.25
# 50%        3,146,280.00          314,255.00    31.00        253,196.50
# 75%        4,119,189.50          411,757.50    41.00        680,390.00
# max        5,300,108.00          530,010.00    53.00    828,980,608.00
#
#        Produto Interno Bruto per capita, a preços correntes(R$ 1,00)  \
# count                                           5,570.00
# mean                                           33,871.28
# std                                            41,908.72
# min                                             5,407.66
# 25%                                            12,831.15
# 50%                                            23,401.17
# 75%                                            40,807.45
# max                                           920,833.97
#
#        Salário médio mensal(R$)  qtd_familias_total_bolsa_familia  \
# count                  5,536.00                          5,464.00
# mean                   2,214.31                         26,254.14
# std                      493.57                        104,048.62
# min                    1,052.27                             29.00
# 25%                    1,883.98                          3,757.75
# 50%                    2,133.77                          9,976.00
# 75%                    2,434.29                         25,140.75
# max                    6,463.69                      5,096,329.00
#
#        media_qtd_familias_bolsa_familia  valor_total_repassado_bolsa_familia  \
# count                          5,464.00                             5,464.00
# mean                           2,625.41                         3,011,198.47
# std                           10,404.86                        10,144,809.90
# min                                2.90                             2,958.00
# 25%                              375.77                           385,735.00
# 50%                              997.60                         1,156,918.00
# 75%                            2,514.07                         3,096,483.75
# max                          509,632.90                       500,125,149.00
#
#        media_valor_repassado_bolsa_familia  ...  num_pcd_beneficiados_bpc  \
# count                             5,464.00  ...                  5,464.00
# mean                            301,119.85  ...                  5,554.38
# std                           1,014,480.99  ...                 22,731.26
# min                                 295.80  ...                      0.00
# 25%                              38,573.50  ...                    544.00
# 50%                             115,691.80  ...                  1,512.50
# 75%                             309,648.38  ...                  4,471.00
# max                          50,012,514.90  ...                936,763.00
#
#        media_pcd_beneficiados_bpc  num_idoso_beneficiados_bpc  \
# count                    5,463.00                    5,464.00
# mean                       462.95                    4,612.50
# std                      1,894.43                   31,111.54
# min                          0.00                        0.00
# 25%                         45.33                      214.00
# 50%                        126.08                      706.50
# 75%                        372.58                    2,428.50
# max                     78,063.58                1,566,808.00
#
#        media_idoso_beneficiados_bpc  valor_total_repassado_bpc  \
# count                      5,463.00                   5,464.00
# mean                         384.45              11,194,682.02
# std                        2,592.86              58,530,033.79
# min                            0.00                       0.00
# 25%                           17.83                 890,453.69
# 50%                           58.92               2,558,094.49
# 75%                          202.42               7,792,738.78
# max                      130,567.33           2,757,353,200.59
#
#        media_valor_repassado_bpc  valor_pcd_repassado_bpc  \
# count                   5,464.00                 5,464.00
# mean                  932,890.17             6,115,267.69
# std                 4,877,502.82            25,029,443.35
# min                         0.00                     0.00
# 25%                    74,204.47               598,405.73
# 50%                   213,174.54             1,664,874.57
# 75%                   649,394.90             4,922,813.67
# max               229,779,433.38         1,031,696,350.58
#
#        media_valor_pcd_repassado_bpc  valor_idoso_repassado_bpc  \
# count                       5,463.00                   5,464.00
# mean                      509,698.93               5,079,414.33
# std                     2,085,966.47              34,263,806.09
# min                             0.00                       0.00
# 25%                        49,867.28                 235,403.21
# 50%                       138,784.87                 777,712.14
# 75%                       410,257.49               2,674,392.88
# max                    85,974,695.88           1,725,656,850.01
#
#        media_valor_idoso_repassado_pbc
# count                         5,463.00
# mean                        423,362.79
# std                       2,855,572.68
# min                               0.00
# 25%                          19,617.14
# 50%                          64,809.36
# 75%                         222,888.52
# max                     143,804,737.50
#
# [8 rows x 22 columns]
